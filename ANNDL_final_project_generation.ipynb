# %% [markdown]
# ## ANNDL Final Project: Jeopardy! Question Generation

# %%
# This notebook will train an LSTM on a set of Jeopardy! questions with the goal of producing novel questions.
# NOTE: Some code (notably `sample` and `on_epoch_end`) is from content provided in classwork.

# %%
import csv
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
import random
import sys
from keras.callbacks import LambdaCallback

# %%
# Load and clean data.
data = []
with open("/Users/fiordali/Downloads/JEOPARDY_CSV.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)                                # Skip header line.
    for row in reader:
        if "<" not in row[5]:                   # Exclude videos/photos, questions with formatting.
            data.append(row[5])                 # Keep only question text.

# %%
# Break into train data.
text = " ".join(row for row in data[:10000])

# %%
# Map characters to indices, vice versa.
chars = sorted(list(set("".join(row for row in data))))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
# Find length of longest training question by character.
maxlen = 0
counter = 0

for question in train_questions:
    for letter in question:
        counter += 1
    if counter > maxlen:
        maxlen = counter
    counter = 0

# %%
# Create fixed-length "questions" to train on.
seqlen = 100
step = seqlen
question_snips = []
for i in range(0, len(text) - seqlen - 1, step):
    question_snips.append(text[i: i + seqlen + 1])

# %%
# Turn every question into vector indicating which letter is present (in x) or next (in y) at that point in the sequence.
# seqlen = maxlen                                # Length in chars of longest question
x = np.zeros((len(question_snips), seqlen, len(chars)), dtype=np.bool) 
y = np.zeros((len(question_snips), seqlen, len(chars)), dtype=np.bool) 
for i, question in enumerate(question_snips):
    for t, (char_in, char_out) in enumerate(zip(question[:-1], question[1:])):
        x[i, t, char_indices[char_in]] = 1      # Log which character is present at current spot in the sequence.
        y[i, t, char_indices[char_out]] = 1     # Log what the next character is in the sequence.

# %%
# Model structures.
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars)), return_sequences=True))
model.add(Dense(len(chars), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(learning_rate=0.01),
    metrics=['categorical_crossentropy', 'accuracy']
)

def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)  # softmax
    preds = preds / np.sum(preds)                #
    probas = np.random.multinomial(1, preds, 1)  # sample index
    return np.argmax(probas)                     #

def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text."""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(question_snips) - seqlen - 1)
    
    for diversity in [0.2, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        # Seed for generated question is the start of a random question from training set
        question = text[start_index: start_index + seqlen]
        generated += question
        print('----- Generating with seed: "' + question + '"')
        sys.stdout.write(generated)

        for i in range(200):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(question):
                x_pred[0, t, char_indices[char]] = 1.
            
            preds = model.predict(x_pred, verbose=0)
            next_index = sample(preds[0, -1], diversity)
            next_char = indices_char[next_index]

            question = question[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print("\n\n")

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback])
# Out:
# Epoch 1/50
# 7957/7957 [==============================] - 30s 4ms/step - loss: 3.0782 - categorical_crossentropy: 3.0782 - accuracy: 0.2103
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ution of Mass., second President of the United States In the title of an Aesop fable, this insect sh"
# ution of Mass., second President of the United States In the title of an Aesop fable, this insect she the the the the this the the the the the " fore the the the the the the the the the the the thes "of the the the the the the the the the the the The the the the the the the the the this the the the
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ution of Mass., second President of the United States In the title of an Aesop fable, this insect sh"
# ution of Mass., second President of the United States In the title of an Aesop fable, this insect shis of an he f conthisouine of car The the amer the of be thes ane this the bamte the the the the an inlin "Awof lithe she thin pas the oofere thes Hopr wonc in "19990400 the this oof ide in arte of th
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ution of Mass., second President of the United States In the title of an Aesop fable, this insect sh"
# ution of Mass., second President of the United States In the title of an Aesop fable, this insect shisezMtikibe Puip ofa thodtEching & Dumtrs All the wonmeurend oritheobemdtJlstom cer  orceim in of M.ames arl Hhuree ofaphasufo9 199900tuthe pstilis eri diaviwliceste Mindde th rartdes Theek simen" 192
#
#
# Epoch 2/50
# 7957/7957 [==============================] - 34s 4ms/step - loss: 2.4329 - categorical_crossentropy: 2.4329 - accuracy: 0.3217
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "Calling" album Cross-country skiing is sometimes referred to by these 2 letters, the same ones used "
# Calling" album Cross-country skiing is sometimes referred to by these 2 letters, the same ones used this this this this this mant this this this this com this stom the shat this this stont was this this this this this this this this this this this this this this this cant of this this this some the
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "Calling" album Cross-country skiing is sometimes referred to by these 2 letters, the same ones used "
# Calling" album Cross-country skiing is sometimes referred to by these 2 letters, the same ones used this cast rat the star cat shes this the U.S. a this this the 1950 the U.S.'s prath this count in 1993 this prom this com his some of this cond of this this stat a grom has the sat stit In's this Five
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "Calling" album Cross-country skiing is sometimes referred to by these 2 letters, the same ones used "
# Calling" album Cross-country skiing is sometimes referred to by these 2 letters, the same ones used wan fricat this thos cale & Frmmkere, dates of this plgatn Hous its 1968 fots mast'N Gedlont aloned in inels Rory the pell hidist & thle a wam pro wolb ry"Pe, this Gutling mogettcam sinsy fort Das (co
#
#
# Epoch 3/50
# 7957/7957 [==============================] - 35s 4ms/step - loss: 2.1965 - categorical_crossentropy: 2.1965 - accuracy: 0.3736
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " since Cicero 1 of the 2 born in Vermont When it began on Pan Am & Qantas in the late '70s, it was b"
#  since Cicero 1 of the 2 born in Vermont When it began on Pan Am & Qantas in the late '70s, it was be this stert for the stat stat the lith of the cont a stating the first the 1968 the 1998 the with the first the fitst of this state the canting the U.S. the first of this state this state the conting
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " since Cicero 1 of the 2 born in Vermont When it began on Pan Am & Qantas in the late '70s, it was b"
#  since Cicero 1 of the 2 born in Vermont When it began on Pan Am & Qantas in the late '70s, it was bean the dist the stating the Clitst reperter This dis coll as a plays called a wer the Calling this contry the 1958 the 1969, the 1998 This shat in this stort the 1996 the argent of this bus this cond
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " since Cicero 1 of the 2 born in Vermont When it began on Pan Am & Qantas in the late '70s, it was b"
#  since Cicero 1 of the 2 born in Vermont When it began on Pan Am & Qantas in the late '70s, it was bansuriis This spents with. vial" of a atednys Dutth of Grandithon 1899 the namec Copenrwas de of she whow  Alenamed nam Fack on deaw Flack Denphasth for the have" Yor Phime & Fefst shis lew this nor e
#
#
# Epoch 4/50
# 7957/7957 [==============================] - 37s 5ms/step - loss: 2.0661 - categorical_crossentropy: 2.0661 - accuracy: 0.4097
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: ""...you are a credit to your craft, your race and to your family" In geologic time one of these, sho"
# "...you are a credit to your craft, your race and to your family" In geologic time one of these, show & the first popplan of this country of the first country of the first country of the right of this country of the san a prom the country of the first country of the first country of the part of this
#
#
# ----- diversity: 0.5
# ----- Generating with seed: ""...you are a credit to your craft, your race and to your family" In geologic time one of these, sho"
# "...you are a credit to your craft, your race and to your family" In geologic time one of these, shore the propart of the latical allies a part batt of this bork to the Brom "Bove WWI Wenting a lang in this who for the country was the name of the cortry of the first devill of this one is a pritic no
#
#
# ----- diversity: 1.0
# ----- Generating with seed: ""...you are a credit to your craft, your race and to your family" In geologic time one of these, sho"
# "...you are a credit to your craft, your race and to your family" In geologic time one of these, show headon's abous stors was the rimarkis & this joun Flick Jotcoims 1999 CuScention Gar'h paroll bewogenic from that in the ampucticoll aginn Ni. 5 rnfort at Nammoin Choy K,! This redirtt, livial sympr
#
#
# Epoch 5/50
# 7957/7957 [==============================] - 31s 4ms/step - loss: 1.9758 - categorical_crossentropy: 1.9758 - accuracy: 0.4347
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ol; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma in this state has a record average"
# ol; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma in this state has a record average seen to the said to the name the first first part of this sean to the sear to the gear to the first to the state that the first part for the way first part to the said to the first part to the first
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ol; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma in this state has a record average"
# ol; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma in this state has a record average leng to the genten as the man leatent colled with this name was carsing this stare first parted in the manier the ging the name to king first live for the elumes Is a called that the stare to played
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ol; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma in this state has a record average"
# ol; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma in this state has a record average prisidentent seefing,: Chipt; this No lake a precect & elans seet" be agher 83, 1972, he arsofd-ment were “Uthe Drid than's you of arrip toil" mady in the peasser's startingt fing outle lang teent by
#
#
# Epoch 6/50
# 7957/7957 [==============================] - 31s 4ms/step - loss: 1.9073 - categorical_crossentropy: 1.9073 - accuracy: 0.4544
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "r a carrier for him that fits under an airplane seat He's considered the author of the Pentateuch, w"
# r a carrier for him that fits under an airplane seat He's considered the author of the Pentateuch, was the state of the mand in 1972 this state the send with the first the was the place the first the first the mand of a state of the mand in the 1992 comment of the motter the first the with this coun
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "r a carrier for him that fits under an airplane seat He's considered the author of the Pentateuch, w"
# r a carrier for him that fits under an airplane seat He's considered the author of the Pentateuch, with this No. 1 were frond, this musical state as a this bring this company of the first that city store brokn form this "of the first company in 1942 this state in 1932 this crast "The The sond with t
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "r a carrier for him that fits under an airplane seat He's considered the author of the Pentateuch, w"
# r a carrier for him that fits under an airplane seat He's considered the author of the Pentateuch, wan sheat, dit have to door ent compaind-thero, him Amstroppan west with recccest comole Finds 'or froned take monns" in 1991, Pring that then 1986 Jran thon's a mill wand that med sity was forl taing
#
#
# Epoch 7/50
# 7957/7957 [==============================] - 27s 3ms/step - loss: 1.8528 - categorical_crossentropy: 1.8528 - accuracy: 0.4687
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "o might be a little demon!) Karl led the first of these Marxist organizational efforts; the second o"
# o might be a little demon!) Karl led the first of these Marxist organizational efforts; the second of the movie to the first to the played the first to the top to the first to the first to the state of the first to the first to the state of these of these to the look to the now his first winds to th
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "o might be a little demon!) Karl led the first of these Marxist organizational efforts; the second o"
# o might be a little demon!) Karl led the first of these Marxist organizational efforts; the second of the Mexic to the president of these state were to ground in the most for the and Marchean in the first love to the come to the liced as the lover to the deenian are to the dought in the first one of
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "o might be a little demon!) Karl led the first of these Marxist organizational efforts; the second o"
# o might be a little demon!) Karl led the first of these Marxist organizational efforts; the second of Aix Excection of this remory people sinded known weathers of this bas View known is world in him 3 Jale-one moones known For "Firmick Cowing hotit you dofens" it to the places in "TheonPilles & Rifi
#
#
# Epoch 8/50
# 7957/7957 [==============================] - 34s 4ms/step - loss: 1.8088 - categorical_crossentropy: 1.8088 - accuracy: 0.4809
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: " device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Wolfgan"
#  device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Wolfgand in the first prided the first freed the first from the first from the stared from the collection of the first show they college of the first printed in the first senger of the first from the world i
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Wolfgan"
#  device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Wolfgand was preceded a boath of they could family may said, it's that sea of the fired one of the see this way success are this colded the word printed a secred dogical called a layer in the formed these wa
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Wolfgan"
#  device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Wolfgances of "cellerge String dowladist" A man to after flaversy Allowink planced "Therendd Durior, beadssed if eddactere, the liofers of accian in Grying who this corved his man from to red theids end iss
#
#
# Epoch 9/50
# 7957/7957 [==============================] - 30s 4ms/step - loss: 1.7743 - categorical_crossentropy: 1.7743 - accuracy: 0.4910
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ded a huge bribe from U.S. diplomats Objects that pass closer to the sun than Mercury have been name"
# ded a huge bribe from U.S. diplomats Objects that pass closer to the sun than Mercury have been name for a sport of this capital of this state in this country In 1996 this state in the 1990s This country whose starring is a seary of this country is a country in 1995 It's a state in 1996 In 1996 this
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ded a huge bribe from U.S. diplomats Objects that pass closer to the sun than Mercury have been name"
# ded a huge bribe from U.S. diplomats Objects that pass closer to the sun than Mercury have been name shew a sport to may in this scoress was first for this time many was includes sisker in 1997, "The State of The fame of the langetion in 1959 This type of from the Bersinna was president with a 1992
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ded a huge bribe from U.S. diplomats Objects that pass closer to the sun than Mercury have been name"
# ded a huge bribe from U.S. diplomats Objects that pass closer to the sun than Mercury have been name name In 100 siland Damma is show Lehms Lichy Ie cred aid, or "Gephasowia" Princessized for a trake son Joney was afterguled, kike south, 1990 grandy of mainest hor a Byachuse Rickura in Jary Clice wa
#
#
# Epoch 10/50
# 7957/7957 [==============================] - 31s 4ms/step - loss: 1.7456 - categorical_crossentropy: 1.7456 - accuracy: 0.4992
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: " toys precede "On Fire" in the name of a Radio Disney top 30 band; do you? Peaches are more than 80%"
#  toys precede "On Fire" in the name of a Radio Disney top 30 band; do you? Peaches are more than 80% of the president in the 1990s State is the president in the 1990s & the president in the 1970s The title for the largest in the 1930s the title capital is the president of the president in the 1960s
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " toys precede "On Fire" in the name of a Radio Disney top 30 band; do you? Peaches are more than 80%"
#  toys precede "On Fire" in the name of a Radio Disney top 30 band; do you? Peaches are more than 80% of the president by the seat of the 3 reaction presidents in the 1900s The sect on a president of the Capital The was an activition in 1979 teather to the record president in the 1997 film that presi
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " toys precede "On Fire" in the name of a Radio Disney top 30 band; do you? Peaches are more than 80%"
#  toys precede "On Fire" in the name of a Radio Disney top 30 band; do you? Peaches are more than 80% on the 19th century this lake eatling name were wave a n.C. marriate, ly matery name; 94 lobd of Roite staties The way the scientes comenty capption dy carded sutchillob that whet secriple in "Railif
#
#
# Epoch 11/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.7226 - categorical_crossentropy: 1.7226 - accuracy: 0.5050
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "your family" In geologic time one of these, shorter than an eon, is divided into periods & subdivide"
# your family" In geologic time one of these, shorter than an eon, is divided into periods & subdivide of this state for this country to this country that the secret of the state can be this man was the state of this country him by this country star was a played this country that the secred on the sec
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "your family" In geologic time one of these, shorter than an eon, is divided into periods & subdivide"
# your family" In geologic time one of these, shorter than an eon, is divided into periods & subdivide this to be this word might some of this Arien Ochose word for this city that this Canish was a movie Christory, the second of the sea for a main is a long by this country for the mother Sing of these
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "your family" In geologic time one of these, shorter than an eon, is divided into periods & subdivide"
# your family" In geologic time one of these, shorter than an eon, is divided into periods & subdivide Its name Of Arler out drow become in 1938: Maryashim 42 & the cont in its south A Wean heard sheriful park to aloyerse of these for higher take to countred byong back Parky, whose fregar local soll s
#
#
# Epoch 12/50
# 7957/7957 [==============================] - 34s 4ms/step - loss: 1.7014 - categorical_crossentropy: 1.7014 - accuracy: 0.5114
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "displayed on "And away we go" Cows regurgitate this from the first stomach to the mouth & chew it ag"
# displayed on "And away we go" Cows regurgitate this from the first stomach to the mouth & chew it against the court of the popular in the title of this time in this court in the court of the court in the real the title of the title of the times in this country The state in the title of the court of
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "displayed on "And away we go" Cows regurgitate this from the first stomach to the mouth & chew it ag"
# displayed on "And away we go" Cows regurgitate this from the first stomach to the mouth & chew it agains of the life with a woman the right play is the last from the ince of the name of this turned in the title of the Caradies & White of the Communic was a state in this for the title of the court in
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "displayed on "And away we go" Cows regurgitate this from the first stomach to the mouth & chew it ag"
# displayed on "And away we go" Cows regurgitate this from the first stomach to the mouth & chew it age it will day implocations of & of the Ctull, Martle is hwed at this carct the real are is ches of 5 Deroped him is firating the largs in the such at a rockes after a in a wead of author git, "Whenet
#
#
# Epoch 13/50
# 7957/7957 [==============================] - 28s 3ms/step - loss: 1.6843 - categorical_crossentropy: 1.6843 - accuracy: 0.5159
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "tina Applegate's in 2001 In 2004 United launched this new service that features low fares & more sea"
# tina Applegate's in 2001 In 2004 United launched this new service that features low fares & more seat of the title company the high of the first country in the 1970s in the 1970s this country In 1977 the first start of the first the trapper of the transpite to the country in the 1970s The first coun
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "tina Applegate's in 2001 In 2004 United launched this new service that features low fares & more sea"
# tina Applegate's in 2001 In 2004 United launched this new service that features low fares & more sea on the main this played the 3 material star of this country In 1971 this type of the state that works of the propostition of the New Yorking is a spirit, the seat of the Statue Boston in the first pr
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "tina Applegate's in 2001 In 2004 United launched this new service that features low fares & more sea"
# tina Applegate's in 2001 In 2004 United launched this new service that features low fares & more seaped this grout On the drick all ape sorn in the tagan from Mignel it toous Sochool Lain This stuff as pitceen of amfill in Meachel Soll Sig Mashecemy are norther" In "Shoy "He was Cailfrection 3" O'N.
#
#
# Epoch 14/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.6697 - categorical_crossentropy: 1.6697 - accuracy: 0.5201
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: " closer to the sun than Mercury have been named for this mythological figure It's the largest kingdo"
#  closer to the sun than Mercury have been named for this mythological figure It's the largest kingdom of this state in this 1989 film in this state to this state of this state in 1999 This author of this state are contraction of this country This state is the sun are the second in this country In 19
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " closer to the sun than Mercury have been named for this mythological figure It's the largest kingdo"
#  closer to the sun than Mercury have been named for this mythological figure It's the largest kingdom of this returned to this space in this country This "Good to the Mountaining" In August 1980 the South Annener on this country in 1967 this creature to this subart to this entromed in a Broadway to
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " closer to the sun than Mercury have been named for this mythological figure It's the largest kingdo"
#  closer to the sun than Mercury have been named for this mythological figure It's the largest kingdoning & Pormand hamplated out cetent Jackbem If it's a can'bel one's one by India of the 19th century inangha of Com Castice In Novem Fears in this brush became the Chmol's Robero M.I In 1998 Druch Oro
#
#
# Epoch 15/50
# 7957/7957 [==============================] - 29s 4ms/step - loss: 1.6563 - categorical_crossentropy: 1.6563 - accuracy: 0.5235
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "LM, creating Europe's largest airline Philadelphia got its start as a colony for this religious grou"
# LM, creating Europe's largest airline Philadelphia got its start as a colony for this religious group of this company was the state was the first product of the state was the state who desped this control convention in the state are state was the mountain for this officers from the state of the firs
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "LM, creating Europe's largest airline Philadelphia got its start as a colony for this religious grou"
# LM, creating Europe's largest airline Philadelphia got its start as a colony for this religious group are word from the first from the fronterance that starred in the title of this convicted the language in the first prosecially this statient starred in the British warther in the sign of the Stories
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "LM, creating Europe's largest airline Philadelphia got its start as a colony for this religious grou"
# LM, creating Europe's largest airline Philadelphia got its start as a colony for this religious group Dadellander & you river This drum father project one of these after witly having "longer with and bluece reolude these", it's al" this explorery in "Nelwow Told" Amentatians naves high-celly the vit
#
#
# Epoch 16/50
# 7957/7957 [==============================] - 29s 4ms/step - loss: 1.6461 - categorical_crossentropy: 1.6461 - accuracy: 0.5258
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma "
# tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma the only the season in the 1990s The first for the world called the season of this country was a sport of the said to the water was the first state in the world to the season of the season that called
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma "
# tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma The series of the late country is the water a based in 1994 these called the singer in the world's offer the world his field This country in the 1990s The largest The show A title called the season is
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma "
# tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The city of Yuma  & Over wat of Maric Sabunton from 1911:  thougs in Newmon once has first world, 1918 to 4Mquanded trilition 80 years ox-singer of the Fastace in his often 50-mal, it was the first than the couplomess
#
#
# Epoch 17/50
# 7957/7957 [==============================] - 34s 4ms/step - loss: 1.6345 - categorical_crossentropy: 1.6345 - accuracy: 0.5297
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "s, it was basically a roped-off part of the economy cabin with free drinks Ali, who married this man"
# s, it was basically a roped-off part of the economy cabin with free drinks Ali, who married this man are son of the control of this constitution of this completing the first state in this complete is the title of the complete in the 1993 common of this completion of this man also completing this com
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "s, it was basically a roped-off part of the economy cabin with free drinks Ali, who married this man"
# s, it was basically a roped-off part of the economy cabin with free drinks Ali, who married this man as this top of the first product of this completion of the British for "state "The Hand of the Kears" This word for a direction of this first second in 2003 to the 1863 held the first of the term for
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "s, it was basically a roped-off part of the economy cabin with free drinks Ali, who married this man"
# s, it was basically a roped-off part of the economy cabin with free drinks Ali, who married this many meating up of this a carpethy From the vinement telomed its car as North & defend in 2003 to low A conventioned coom for aning of it-become that convention volurion of the resegistly of applaret, &
#
#
# Epoch 18/50
# 7957/7957 [==============================] - 36s 4ms/step - loss: 1.6254 - categorical_crossentropy: 1.6254 - accuracy: 0.5319
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "Maize is another word for this Of the 6 noble gases on the periodic table, it is the lightest 11-yea"
# Maize is another word for this Of the 6 noble gases on the periodic table, it is the lightest 11-year the first commercial are this company of this comerginal is the first state in this country was a comergine star with this completed on this completeration of this commercial state in 1954, this cou
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "Maize is another word for this Of the 6 noble gases on the periodic table, it is the lightest 11-yea"
# Maize is another word for this Of the 6 noble gases on the periodic table, it is the lightest 11-year of this African speakers in 1963 This coush on the Inded this city's "Juliet" is a land meaning this Pennishistiel starred this between this completed on this state who first this in this country Th
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "Maize is another word for this Of the 6 noble gases on the periodic table, it is the lightest 11-yea"
# Maize is another word for this Of the 6 noble gases on the periodic table, it is the lightest 11-year forming the fubullius Paregery Nexamonic flag is the "gill-dreends oftangy downal the vision"'s "Freatest Relipion," catcheta; thing: "At Argura, Brithar Bark & Americon South "Harkey Septernaty" th
#
#
# Epoch 19/50
# 7957/7957 [==============================] - 30s 4ms/step - loss: 1.6166 - categorical_crossentropy: 1.6166 - accuracy: 0.5341
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: " combine with light energy to create oxygen & glucose The perfect waves of New Zealand's Piha Beach "
#  combine with light energy to create oxygen & glucose The perfect waves of New Zealand's Piha Beach of this country The state In 1999 this countries of this country The state was the main this area to the state are the state of the March 1999 to 1999 this country The first film, this country The fir
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " combine with light energy to create oxygen & glucose The perfect waves of New Zealand's Piha Beach "
#  combine with light energy to create oxygen & glucose The perfect waves of New Zealand's Piha Beach & the City Stated of the Holiday Ship or low her first propercion of a trades that starred in the state named for her state, we have the fired a branch of this man's Stiffed of the Pat State & the Lat
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " combine with light energy to create oxygen & glucose The perfect waves of New Zealand's Piha Beach "
#  combine with light energy to create oxygen & glucose The perfect waves of New Zealand's Piha Beach Aredisis, is a 1953-18th counally sirred with: WEBC. The first right-of the late on a titlibe Fleeser" to insect do this, American countral cance meanion, punalce is April 2 fires "The NBC Idurems", I
#
#
# Epoch 20/50
# 7957/7957 [==============================] - 27s 3ms/step - loss: 1.6099 - categorical_crossentropy: 1.6099 - accuracy: 0.5364
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "or this Of the 6 noble gases on the periodic table, it is the lightest 11-year-old Ashlyn White won "
# or this Of the 6 noble gases on the periodic table, it is the lightest 11-year-old Ashlyn White won the this alliteration of the season on the seen here in the 1980s he was the the main as a show of this company's comedy a production of the the season on the sea on the this are a largest one of the
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "or this Of the 6 noble gases on the periodic table, it is the lightest 11-year-old Ashlyn White won "
# or this Of the 6 noble gases on the periodic table, it is the lightest 11-year-old Ashlyn White won a synthed in the may have look called the seen here in the 1840s sepories in the 1996 Colorado Will Bonness of the 1st has a type of sheeph in the power who was a ballet in this show Prone governor of
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "or this Of the 6 noble gases on the periodic table, it is the lightest 11-year-old Ashlyn White won "
# or this Of the 6 noble gases on the periodic table, it is the lightest 11-year-old Ashlyn White won the scientightituted, this schoolshone the nevel change this popular, or 16 Wears president of the film "sold into the city in the Like Han" Day Harvask Thomas Perno; Soill for you'd-befinifies the fi
#
#
# Epoch 21/50
# 7957/7957 [==============================] - 27s 3ms/step - loss: 1.6021 - categorical_crossentropy: 1.6021 - accuracy: 0.5381
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "inier Paradise Ranger Station in this state This housewares store was named for the packaging its me"
# inier Paradise Ranger Station in this state This housewares store was named for the packaging its means "The Longest of the Late of the Late of the Later Beature" is a served as the the first produce of the first produce in the 1994 Charles former The one of the first state can be a company was a se
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "inier Paradise Ranger Station in this state This housewares store was named for the packaging its me"
# inier Paradise Ranger Station in this state This housewares store was named for the packaging its meat common action she was a many the the seat in 1884 The first deperting the the indepenting in 1994 In 1971 this name the crup for a word for a contraipers this composer was suggest became the write
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "inier Paradise Ranger Station in this state This housewares store was named for the packaging its me"
# inier Paradise Ranger Station in this state This housewares store was named for the packaging its meat statce celence Kilmer's rutications The ours & even used ever, also his baster horiday is an Ama9-mpor addition agment with the Nang in this coove the U.S. in Venect & he deatted in 1957 RObeatess
#
#
# Epoch 22/50
# 7957/7957 [==============================] - 27s 3ms/step - loss: 1.5959 - categorical_crossentropy: 1.5959 - accuracy: 0.5394
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "lympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The c"
# lympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The company to the state for this country's product of this country's state company to the state conson in this state said to the state composer This country's state to the state comedy of these state comp
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "lympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The c"
# lympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The capital is this tourne the retitle the note of the trop seen here in the language of this home of the British senting this birth to see common of this seen here of this rest of this to the first of the
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "lympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The c"
# lympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves The chuec offered this 17th century, WWI start rands gival stufff in 1975 Arthes' longest accibul carain teen blotwing comes from the stack Vanne Lones She means long was bood to town to huge This more pop
#
#
# Epoch 23/50
# 7957/7957 [==============================] - 28s 3ms/step - loss: 1.5900 - categorical_crossentropy: 1.5900 - accuracy: 0.5415
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "rubber ball while picking up 6-pronged metal objects It can be a separating line in your hair or a r"
# rubber ball while picking up 6-pronged metal objects It can be a separating line in your hair or a record of this country The state of this country The second of this country This state is the state and the state of this state as this state of this country The state of this country This comedy of th
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "rubber ball while picking up 6-pronged metal objects It can be a separating line in your hair or a r"
# rubber ball while picking up 6-pronged metal objects It can be a separating line in your hair or a religious state Author of the Bather Bronco Anthony The same in the 1810s & to be a sonn in this color is called the based as this capital of the first off Rubsith of this state as a moved this artist
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "rubber ball while picking up 6-pronged metal objects It can be a separating line in your hair or a r"
# rubber ball while picking up 6-pronged metal objects It can be a separating line in your hair or a raigh is awatively to applasion in the 1500s; this topporain childran helped from this slips is the act catchaked shaped became uptive sayign to your jointanopen & somethinged bingew's Top "Womeol Bewt
#
#
# Epoch 24/50
# 7957/7957 [==============================] - 26s 3ms/step - loss: 1.5842 - categorical_crossentropy: 1.5842 - accuracy: 0.5428
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: " or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bouncing a b"
#  or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bouncing a based on the star of the first first starter & the star of the first started in 1917 is the first of the screen are struck in the 1984 British are the first country The first considered the surville fo
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bouncing a b"
#  or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bouncing a betwer in 2004, the December of the Beautury the babrcition of the British in the 1985 first 1971 for the Bent the name of the Paradia is from the Most for "The Greece Direct" was the first for the 4 d
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bouncing a b"
#  or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bouncing a big scoporatumes in Of New Hampelos of the becansiny diffesting the surveletate with 40 Bumpting crass guys" Me infatumeses to the Milon' Neware Wars is planet Juff was waseb's the runger (No Demown Da
#
#
# Epoch 25/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5792 - categorical_crossentropy: 1.5792 - accuracy: 0.5445
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "ter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state "
# ter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state in 1997 in 1997 in 1971 In 1991 this cardinal star of this man with this "cours" in 1997 was the first to an an ingline of this country The first state was a state to this type of this country in 1997
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state "
# ter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state was the world more for this "radiom "By Unte Mackinally" The work was the made of this This "author of the said that a lead" this form of the Broadway based on this city, this 1928 played this capital
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state "
# ter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state From the Style in 1617 In 1977 this Irelation would model methodno of a way this He was shot He drifgs was the first 4) Mary writing, in 1913 Gailont back as this crafting after to nothird with theign
#
#
# Epoch 26/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5749 - categorical_crossentropy: 1.5749 - accuracy: 0.5448
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "ization's 2009 World Series This hero of several books is 11 when he discovers he's a wizard A 7.0 m"
# ization's 2009 World Series This hero of several books is 11 when he discovers he's a wizard A 7.0 mallar in this country was the first star of this state in this city This part of this country The started in this started in the 1960s The title of this started in this country The started in this cit
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ization's 2009 World Series This hero of several books is 11 when he discovers he's a wizard A 7.0 m"
# ization's 2009 World Series This hero of several books is 11 when he discovers he's a wizard A 7.0 million forms in this state won a speaken This large the 1990s is a star at the main outlane include speciales the name of the Greek for "interest talls" The Greek for "interest in the Stair" this "The
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ization's 2009 World Series This hero of several books is 11 when he discovers he's a wizard A 7.0 m"
# ization's 2009 World Series This hero of several books is 11 when he discovers he's a wizard A 7.0 medical can't reclierin wall Fouthin "swau" In a strurks the everyone to referting known fouthoousist futures unce, an din star of these person Canin Marnin in 1885 to fiold like you was "could" from t
#
#
# Epoch 27/50
# 7957/7957 [==============================] - 29s 4ms/step - loss: 1.5699 - categorical_crossentropy: 1.5699 - accuracy: 0.5466
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: "d navigation& ranging is the full name for this device that bounces radio waves underwater Small, sl"
# d navigation& ranging is the full name for this device that bounces radio waves underwater Small, slavery of this country in 1964 In 1904 this country for this man who was a state can be a branch of this man between this country This title of this country to the most country for this ballet this cou
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "d navigation& ranging is the full name for this device that bounces radio waves underwater Small, sl"
# d navigation& ranging is the full name for this device that bounces radio waves underwater Small, slage furn's living for this type of this race state Supannan screen reserve to can be apprence called "A planet" this Eurth British play The magic career the Europe only transparent in 1974 This time o
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "d navigation& ranging is the full name for this device that bounces radio waves underwater Small, sl"
# d navigation& ranging is the full name for this device that bounces radio waves underwater Small, slidee!  that's pitcher: he centcry a ploting told nugh in 2004, he southern first producease "Fayhago" 1964: Michoon to the scouple band in a brunk Sarandoup hostancee, he "peeickers", you're juggine"
#
#
# Epoch 28/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5655 - categorical_crossentropy: 1.5655 - accuracy: 0.5473
#
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ----- Generating with seed: "company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a  mo"
# company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a  movement of this country of this country In this 1997 film This state in this 1987 film starred in this 1991 million started this state in this country This country This state was a species of this coun
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a  mo"
# company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a  movinations that it was can be made "the little corress in this story became this 1954 This cornor became the late became a common this company's "Angels Steppen State in the U.S. at the state famous fo
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a  mo"
# company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a  most they won currents as it was the gratually man sopping promined hero High jeturior of 2 "Utebs Bond", knows her national girl helder this munk abbeil neal known be soction was and name African rangn
#
#
# Epoch 29/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5620 - categorical_crossentropy: 1.5620 - accuracy: 0.5485
#
# ----- Generating text after Epoch: 28
# ----- diversity: 0.2
# ----- Generating with seed: "he Dec. of Indep., framer of the Constitution of Mass., second President of the United States In the"
# he Dec. of Indep., framer of the Constitution of Mass., second President of the United States In the 1980s this true to the stuck of this country was the stuck of the star of this country The state can be a convention of this country The sun in the 1950s The name of this country The state can be a c
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "he Dec. of Indep., framer of the Constitution of Mass., second President of the United States In the"
# he Dec. of Indep., framer of the Constitution of Mass., second President of the United States In the 1960s this species in the first students of this prefers the tree with host of the andrecucted the first for this animal producer to title the sumperes in the highest consing of a low she was a sping
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "he Dec. of Indep., framer of the Constitution of Mass., second President of the United States In the"
# he Dec. of Indep., framer of the Constitution of Mass., second President of the United States In the dost in up resus the 41 word often her history this hards the just that sajes of the show is whrsed in Agaiest oresthie Tratel He cruetment hit more species the Gauriawa Speciatively hunce, bit Perio
#
#
# Epoch 30/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5582 - categorical_crossentropy: 1.5582 - accuracy: 0.5495
#
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: "for this mythological figure It's the largest kingdom in the United Kingdom "Party In The U.S.A." is"
# for this mythological figure It's the largest kingdom in the United Kingdom "Party In The U.S.A." is a company of this type of this title for a starring on this title company to this type of this word for a part of this country in 1977 In 1999 this state in this country in 1978 In 1998 this country
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "for this mythological figure It's the largest kingdom in the United Kingdom "Party In The U.S.A." is"
# for this mythological figure It's the largest kingdom in the United Kingdom "Party In The U.S.A." is the second in a person first team to this company said that this terrival from stard in this many of but in the original made this one of these first metted the mad--inding in 1969, whose name means
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "for this mythological figure It's the largest kingdom in the United Kingdom "Party In The U.S.A." is"
# for this mythological figure It's the largest kingdom in the United Kingdom "Party In The U.S.A." is a "break the barderside; "In William Let TAid" The line can be grown killing on this pradutional found lin, afrected in this poxcender This paral its state ather This freed this magnuagon kind of wif
#
#
# Epoch 31/50
# 7957/7957 [==============================] - 27s 3ms/step - loss: 1.5541 - categorical_crossentropy: 1.5541 - accuracy: 0.5504
#
# ----- Generating text after Epoch: 30
# ----- diversity: 0.2
# ----- Generating with seed: " diplomats Objects that pass closer to the sun than Mercury have been named for this mythological fi"
#  diplomats Objects that pass closer to the sun than Mercury have been named for this mythological first company that in this common bank that this title change that seen here is a serves of this common state was the time this band in this country is a bar that this state of this state convention of
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " diplomats Objects that pass closer to the sun than Mercury have been named for this mythological fi"
#  diplomats Objects that pass closer to the sun than Mercury have been named for this mythological figure of this country for a decast in 1947 It was organization's state was born or win a grain one of these process as a company a main maker of this state in this part of this convict of her state was
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " diplomats Objects that pass closer to the sun than Mercury have been named for this mythological fi"
#  diplomats Objects that pass closer to the sun than Mercury have been named for this mythological first liets in the friens at a sugarizes people This time on a great mensing Mrchuria' King is a dairy this craft bast this catter that whan 7 miles with a fables With 24th character for speed clain...
#
#
# Epoch 32/50
# 7957/7957 [==============================] - 30s 4ms/step - loss: 1.5513 - categorical_crossentropy: 1.5513 - accuracy: 0.5508
#
# ----- Generating text after Epoch: 31
# ...
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " themselves & the second-highest mountain Revolutionary War hero: "His spirit is in Vermont now" A s"
#  themselves & the second-highest mountain Revolutionary War hero: "His spirit is in Vermont now" A strikue is this 11 lives, its knot for in the Cat Tinternal Carra, it was the Mass-perines stitt "A Busmar", the Roby Sola We came of world baseball is the poem from Litty cotcologigate from corvered a
#
#
# Epoch 41/50
# 7957/7957 [==============================] - 29s 4ms/step - loss: 1.5282 - categorical_crossentropy: 1.5282 - accuracy: 0.5570
#
# ----- Generating text after Epoch: 40
# ----- diversity: 0.2
# ----- Generating with seed: "d" This car company has been in the news for widespread recalls of its Corollas & other models As an"
# d" This car company has been in the news for widespread recalls of its Corollas & other models As an experimation to the state could be communist of legend by the state was the largest of the state comes from the 1930s In 1998 the 1996 this country The only the survey as a country The first name of
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "d" This car company has been in the news for widespread recalls of its Corollas & other models As an"
# d" This car company has been in the news for widespread recalls of its Corollas & other models As an ervings of this president was the marine where one of these ancient president company called "I have good more than the portrained in the legend in the largest dish In 1912 Where 2 country This count
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "d" This car company has been in the news for widespread recalls of its Corollas & other models As an"
# d" This car company has been in the news for widespread recalls of its Corollas & other models As an OST for the mick like this designer good that has In 1992 Mark 1, the Barke Walkpirable This country Ravish In 1915 hostinal stills with hersen who wooden chunglist-docts named for a J. State T. 50-m
#
#
# Epoch 42/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5258 - categorical_crossentropy: 1.5258 - accuracy: 0.5572
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: "e Yankees in '27 & '36; "Gibraltar in Cleats" Africa's lowest temperature was 11 degrees below zero "
# e Yankees in '27 & '36; "Gibraltar in Cleats" Africa's lowest temperature was 11 degrees below zero is the name of this country This country This country In 1999 a star in this country In 1999 this country This country This country This country This country This country This country This country In
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "e Yankees in '27 & '36; "Gibraltar in Cleats" Africa's lowest temperature was 11 degrees below zero "
# e Yankees in '27 & '36; "Gibraltar in Cleats" Africa's lowest temperature was 11 degrees below zero or a retirente in Claude His school serves this South American partner of this type of this substance music from this country at the 12th century Chicago are this "Now that a high and the "man" that t
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "e Yankees in '27 & '36; "Gibraltar in Cleats" Africa's lowest temperature was 11 degrees below zero "
# e Yankees in '27 & '36; "Gibraltar in Cleats" Africa's lowest temperature was 11 degrees below zero at Agy Kathtrow During dream, odd game at this Sudper-Namidy" ascares on the first author, proposagural testic dusting of high 1st back to have as as unchanacy stamp in an one Ory Mote books became on
#
#
# Epoch 43/50
# 7957/7957 [==============================] - 27s 3ms/step - loss: 1.5246 - categorical_crossentropy: 1.5246 - accuracy: 0.5579
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: " Libyan deserts are found in this African country "I Never Told You" this alliteratively named singe"
#  Libyan deserts are found in this African country "I Never Told You" this alliteratively named singer of this country with this continent to the state conson the conference considered this country was a southern production of this colorful said to this colorful served as a state words are for "the m
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " Libyan deserts are found in this African country "I Never Told You" this alliteratively named singe"
#  Libyan deserts are found in this African country "I Never Told You" this alliteratively named singer to his first name is a brack tunder this name is an island at this convey, his grandfather for married "The Indies" Them last married the life this country where you do trill on this product distric
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " Libyan deserts are found in this African country "I Never Told You" this alliteratively named singe"
#  Libyan deserts are found in this African country "I Never Told You" this alliteratively named singer This builps destract to an are for "he plants" In 1904 10th shouth is one of these in this desert are called the Cashts, "cubb, will hey seepay" Dorgers Scotte, dibbress" The Slangs Wine flight & on
#
#
# Epoch 44/50
# 7957/7957 [==============================] - 30s 4ms/step - loss: 1.5218 - categorical_crossentropy: 1.5218 - accuracy: 0.5587
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: "row your opponent In 1751 the Penn Provincial Assembly placed the order for this symbol of freedom, "
# row your opponent In 1751 the Penn Provincial Assembly placed the order for this symbol of freedom, the title of these areas the title of the only 18th century the river that seen here in the first of these to the title of the most of the title of the second in the last prime that he was named for t
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "row your opponent In 1751 the Penn Provincial Assembly placed the order for this symbol of freedom, "
# row your opponent In 1751 the Penn Provincial Assembly placed the order for this symbol of freedom, the last movies in the last first name of this first with the title of the most common novels his propritative propredement company's marriaged in the Germaney Artents in the New York Camble in the mo
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "row your opponent In 1751 the Penn Provincial Assembly placed the order for this symbol of freedom, "
# row your opponent In 1751 the Penn Provincial Assembly placed the order for this symbol of freedom, guens Alexander someone whone on the Borgoinal brid-automossive a Recame was called Cheakel, GSo Bubblomagnes & buys for Cammure for his day to different of these birthdays in the Snow of" this betwee
#
#
# Epoch 45/50
# 7957/7957 [==============================] - 29s 4ms/step - loss: 1.5203 - categorical_crossentropy: 1.5203 - accuracy: 0.5590
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "is downy or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for boun"
# is downy or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bounded this state of this state was the first of these they was the first of this state is the first community of this community In 1997 this state is a spoces of this country in this state is the first
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "is downy or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for boun"
# is downy or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bounding a considered this discovered this type of small for the successity on the first character in "Cars" This science of the American George was USA's state In 1997 this "The Second of the Crance" It
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "is downy or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for boun"
# is downy or fuzzy, the fruit's called a peach; if it's smooth, a nectarine 4 x 12 This verb for bounced man harricate is noeth he's must house 64 dide in Princesuntry The Heswasn in one of these Hold of these for proturs song for "The Speates" in this Den Rigave Asian split by "abreple antitious all
#
#
# Epoch 46/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5188 - categorical_crossentropy: 1.5188 - accuracy: 0.5596
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "th of Fez in this country Edward Teller & this man partnered in 1898 to sell high fashions to women "
# th of Fez in this country Edward Teller & this man partnered in 1898 to sell high fashions to women as a state back to the state in the 1965 Duck & the California company that served as a real to be the title of this "The Grants And Bean" The British state to the sea of this state star with a post o
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "th of Fez in this country Edward Teller & this man partnered in 1898 to sell high fashions to women "
# th of Fez in this country Edward Teller & this man partnered in 1898 to sell high fashions to women an in board her a called "The Look Connected Pose Balance" The rest congresses the empless of "The Wilema" In 1958 this singer of this sea for this position of this country In this 1955 Bill Streets i
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "th of Fez in this country Edward Teller & this man partnered in 1898 to sell high fashions to women "
# th of Fez in this country Edward Teller & this man partnered in 1898 to sell high fashions to women he's lott honalffbory" have backuliylist in 1976, Everytom's wometh 1964-2008: He to 5 lived in stort" This explorers family In 1425 this SSA two had government on allotmay's 1956 Dopraturtia grand to
#
#
# Epoch 47/50
# 7957/7957 [==============================] - 29s 4ms/step - loss: 1.5169 - categorical_crossentropy: 1.5169 - accuracy: 0.5600
#
# ----- Generating text after Epoch: 46
# ----- diversity: 0.2
# ----- Generating with seed: "5 This device whose name is from the Italian for "springboard" was perfected in the 1930s Composer W"
# 5 This device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Wall of the Clue Crew of the first company was the first of the first company to the resigned the south of the Indianaptania & the Latin for "form" This country This company of this country The only on
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "5 This device whose name is from the Italian for "springboard" was perfected in the 1930s Composer W"
# 5 This device whose name is from the Italian for "springboard" was perfected in the 1930s Composer War in this country In the 1st Sausads Hales In the Old Carric The Clains In the Latin for "foot to a breaks to restauration of the plas from the Lating Hammer" The company who produced this type of bo
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "5 This device whose name is from the Italian for "springboard" was perfected in the 1930s Composer W"
# 5 This device whose name is from the Italian for "springboard" was perfected in the 1930s Composer Warner & the full laigescaller for the one This state The U.S. was this "gisemy phoneus" In Boshoving hat of 40 miles handed bock For a klinter in her releaking one of the simpless my peace, was blain
#
#
# Epoch 48/50
# 7957/7957 [==============================] - 28s 4ms/step - loss: 1.5164 - categorical_crossentropy: 1.5164 - accuracy: 0.5603
#
# ----- Generating text after Epoch: 47
# ----- diversity: 0.2
# ----- Generating with seed: "ancis Xavier founded the Society of Jesus In 1961 James Brown announced "all aboard" for this train "
# ancis Xavier founded the Society of Jesus In 1961 James Brown announced "all aboard" for this train of this commercial seen here in 1984 In 1998 this commander of this common of this state said this community of this contricting this commercity of this country seen here in this 1999 film Some this t
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ancis Xavier founded the Society of Jesus In 1961 James Brown announced "all aboard" for this train "
# ancis Xavier founded the Society of Jesus In 1961 James Brown announced "all aboard" for this train all action of this "All the and Young it was on the longest and honoring type of this there with a second really from this state Sammar in 1899, this deady from the 1990s, he won the comes from the 19
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ancis Xavier founded the Society of Jesus In 1961 James Brown announced "all aboard" for this train "
# ancis Xavier founded the Society of Jesus In 1961 James Brown announced "all aboard" for this train in Senaturizan called this "Alodge Buima" & into "C'New May'ven in" in blaid of this, who director A baspest, "The Nouride", Location's Lail Perfel off the "hous" Europer VIII, the falled 3 sound in t
#
#
# Epoch 49/50
# 7957/7957 [==============================] - 27s 3ms/step - loss: 1.5136 - categorical_crossentropy: 1.5136 - accuracy: 0.5611
#
# ----- Generating text after Epoch: 48
# ----- diversity: 0.2
# ----- Generating with seed: "omy cabin with free drinks Ali, who married this man's daughter Fatima, is considered by Shia Muslim"
# omy cabin with free drinks Ali, who married this man's daughter Fatima, is considered by Shia Muslims that that this for the plane is the first state for this first seat of this region of this type of this state in this city of this country This career of this country is the first seat of this count
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "omy cabin with free drinks Ali, who married this man's daughter Fatima, is considered by Shia Muslim"
# omy cabin with free drinks Ali, who married this man's daughter Fatima, is considered by Shia Muslim of this city The battle of this island of it but called this man who retried starred in 1885 & of the Mississippi minside of this one of these "den, the electromes" is the first of a sulan is the sta
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "omy cabin with free drinks Ali, who married this man's daughter Fatima, is considered by Shia Muslim"
# omy cabin with free drinks Ali, who married this man's daughter Fatima, is considered by Shia Muslims both side that the has from the Professin Quentian seri, but this syruc charch such as bakes an 1880, this "J.G.rading of Lited this alfact in Queb Woodboadfrate Founder is the place and his nat'lls
#
#
# Epoch 50/50
# 7957/7957 [==============================] - 28s 3ms/step - loss: 1.5133 - categorical_crossentropy: 1.5133 - accuracy: 0.5603
#
# ----- Generating text after Epoch: 49
# ----- diversity: 0.2
# ----- Generating with seed: "tial art in which you try to throw your opponent In 1751 the Penn Provincial Assembly placed the ord"
# tial art in which you try to throw your opponent In 1751 the Penn Provincial Assembly placed the order they was the state considered this country The state class the first of the structure is the state for this state to the state called the California & this proncest of this man who was the state ca
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "tial art in which you try to throw your opponent In 1751 the Penn Provincial Assembly placed the ord"
# tial art in which you try to throw your opponent In 1751 the Penn Provincial Assembly placed the order to compity developed in the Central States is she was was the emys Singing has a state this country was same are called the ground, this man's world in the series is a call to the state for the sta
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "tial art in which you try to throw your opponent In 1751 the Penn Provincial Assembly placed the ord"
# tial art in which you try to throw your opponent In 1751 the Penn Provincial Assembly placed the order Lazy your alphio----"2 more mon the City-for Yelrowed for "hent, keep they nation" in 1972 I've slep, someon & Disneyly or to to get least these 1 caryon am a, he was title together president reso-
