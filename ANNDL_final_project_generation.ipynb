# %% [markdown]
# ## ANNDL Final Project: Jeopardy! Question Generation

# %%
# This notebook will train an LSTM on a set of Jeopardy! questions with the goal of producing novel questions.

# %%
import csv
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
import random
import sys
from keras.callbacks import LambdaCallback

# %%
# Load data.
data = []
with open("/Users/fiordali/Downloads/JEOPARDY_CSV.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)                                # Skip header line.
    for row in reader:
        if "<" not in row[5]:                   # Exclude videos/photos, questions with formatting.
            data.append(row[5])                 # Keep only question text.

# %%
# Break into test data. Train data????
train_questions = data[:10000]

# %%
# Map characters to indices, vice versa.
chars = sorted(list(set("".join(row for row in data))))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
# Find length of longest training question by character.
maxlen = 0
counter = 0

for question in train_questions:
    for letter in question:
        counter += 1
    if counter > maxlen:
        maxlen = counter
    counter = 0

# %%
# Turn every question into vector indicating which letter is present (in x) or next (in y) at that point in the sequence.
seqlen = maxlen                                # Length in chars of longest question
x = np.zeros((len(train_questions), seqlen, len(chars)), dtype=np.bool) 
y = np.zeros((len(train_questions), seqlen, len(chars)), dtype=np.bool) 
for i, question in enumerate(train_questions):
    for t, (char_in, char_out) in enumerate(zip(question[:-1], question[1:])):
        x[i, t, char_indices[char_in]] = 1      # Log which character is present at current spot in the sequence.
        y[i, t, char_indices[char_out]] = 1     # Log what the next character is in the sequence.

# %%
# Model structures.
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars)), return_sequences=True))
model.add(Dense(len(chars), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(learning_rate=0.01),
    metrics=['categorical_crossentropy', 'accuracy']
)

def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)  # softmax
    preds = preds / np.sum(preds)                #
    probas = np.random.multinomial(1, preds, 1)  # sample index
    return np.argmax(probas)                     #

def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text."""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    # start_index = random.randint(0, len(train_questions))
    
    #
    for diversity in [0.2, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        # Seed for generated question is the start of a random question from training set
        question = train_questions[random.randint(0, len(train_questions))][:5]
        generated += question
        print('----- Generating with seed: "' + question + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(question):
                x_pred[0, t, char_indices[char]] = 1.
            
            # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
            preds = model.predict(x_pred, verbose=0)
            next_index = sample(preds[0, -1], diversity)
            next_char = indices_char[next_index]

            question = question[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# Train network, print generated text at end of each epoch.
model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback])
# Out:
# Epoch 1/50
# 10000/10000 [==============================] - 88s 9ms/step - loss: 1.0507 - categorical_crossentropy: 1.0507 - accuracy: 0.5627
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "This "
# This ttaaiaoaasaatetatataattaetaattttaoaoacsaaastacsttttetaataasotatitttatcaotttaeatotolattateaoatataatanteoeottattettetmaaoststtattasitatstsaoaastaatitoeisatsataaoaaaaaaoa tssataattaeatiatastaatttottataaeaaotlstosattaatslaiteisaaaaaasettaocaaaotttaottesaatatailoetattlaetaaattaaatttotaaftiaatoitaaoastasatatettaaaaiattotoatoaoeaitataaatttttstaatlaacaastaitataafatttatttaesaeaoaetaataaaitaatetttataastteaa
# ----- diversity: 0.5
# ----- Generating with seed: "Carol"
# Carolpeo oaeiotoatiitvretasadtepaentetonepttnaoeoDafoe tahoetaatetottsteenintatthtthttlttasssesfmitel o slatt5owa otl cfrataltoofroaatateatttstetoaf asttsetotacastycottaneaoietat ouaotadasaralotepatttooanoaoaoeotatsaaaaainiaeetetwot sotctatotaatsmtipclsciittoaaoooaeleoaleooaltaeatesktratacttesoinneastouoa iatottmolaiasetttlestgadaenltuetetaitahoeogtatliatoanctmsoeaaaado aofelotooothh nsowcnoahoainosoa1
# ----- diversity: 1.0
# ----- Generating with seed: "To th"
# To thu wbtotaitlibutoffaarv"rUentopiacbseuraaaaoyoatnhCsseeLrttauo uoelesficfum;tnahHionayesmnfmrsipfttek pdbCor%ewevfuiinebidealfoerndtitpBu1PéoiamI s.iiT ecbl tlirbmnocanl1hr atarlvksmf8tcs paaa2eeitbaNooyyne; tlCirtvllo0l uplattp1ozumahEawibpenoclptfuet1afiip oelo1bsulhycwfo1rnaEtexbLo.oh5ilaalfw,xats trenVslrYyihbsflaltiMtmwtgamdpoay cLlOhrxs i hauBrcuiwv,sGaae f;emtaL"n1eiingsggsnsstnflenarrtthhp
# Epoch 2/50
# 10000/10000 [==============================] - 89s 9ms/step - loss: 0.8301 - categorical_crossentropy: 0.8301 - accuracy: 0.5576
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "In 15"
# In 15sai  i n      e tt     it iat   c a     s s     t   t  a a       at     i   c  e    a s   t        t   ir   s   s      t          s  s  t       t           a i    a           i t t                aa   a       t t  t  e  e   it  o   i a   a  taa   t   na    a a d a   i s   aa  i t s  a     t  at         t    s i    io    as na             a   i  i      a   s           ts       a  t  a a      s  as
# ----- diversity: 0.5
# ----- Generating with seed: "The F"
# The Fata  elsc ett    rl ttresaiaa   issss   tols ddfr  i srlatc rt  l   teei ls a adic s was  l se  se oys si  e,y otn stdse aaaslii  sir sl aa eai  iiooer ta c rlst s  itt ca a as ,i ar o s soied   aiiirtto ivd eiot  a, s so  slp  otariise tir nimiil-dn altao iaasl  a  aiai  tiat,tolti "t a"it "   taihsaosl  ooalntais"ata ss iostsawpsei   a tnen unn,i aodaar  a tli aeea  i   n leao tls itsana  ais s
# ----- diversity: 1.0
# ----- Generating with seed: "This "
# This  saddpg  zvi wgsb"trs l  "ettaioln eaib-,Y ovie  t i "lleiapiil,f,nx ta l,iabewSrtatowrhlydomc idt iBeir ltrpaiiorn allgps" dnsr:psrcld"se2ec i,w saaBt ihicolbgao scl-ruan,eutase.a,c alt:dclwym ois ltbtue ldrtl "swutcS etsB sgi,",og rruoer utsi i  l l nnOnu srecaltistotduoodgoeircacd-id ssaiy saostna&rtiw t"gaacbsan lodut icnCpnec coaelie rt  aoso "tvghcdidl saleto  cstbiswt as " oarbotp tim wpas
# Epoch 3/50
# 10000/10000 [==============================] - 103s 10ms/step - loss: 0.7558 - categorical_crossentropy: 0.7558 - accuracy: 0.5620
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "Each "
# Each      ia   e i     ii  i  i    o    i       i i s    i i    i   i     o          i a  ii       ii   i  i   i      ai   i    i        o   i a a     i          ii  i i i ii  t  i   i     i       i  i   a ii i  ii isa             i      i   iii  a i i  ia      i       o       i  i        s     i  i i   i i   i   iiii      ii i         i   ii   iii  i   iai  i          iis   ii       i  e   t     a
# ----- diversity: 0.5
# ----- Generating with seed: "This "
# This  sc  a ao ie es s m lisi  s t es ai  i   ioedi sr iai  os i iaooagio  iir  ssiiii i i  ss o i  ti  osi rsi    iio    i  t a    i   o  aea c ai ai iiiiaaasr iiei e soii i nnn bio   iia io ia   aei  eot  i iiiol to"i oi e iiiie aie rri  , ei  ae iaie l a  il a   io    si   lns   itsa" i   i   a taosisiaete e eli e d iari  i   si tiii   i csiiaa iosi i eaa is eis l  e niiai ir  i it   s i     o   e
# ----- diversity: 1.0
# ----- Generating with seed: "Writi"
# Writiiie n"iiaseccom fse"b)pasgii ifa aursnsosl osedtadhtwpn isseaaailaoy ieashbse  sisr   ctby" ,  e"ua aisaeiipfsta    ee  yd  iii  is poloiPtl,pecli aes oe raa h. h aw"ia ohei od lia  sssifttiayto aixopoa,alnee"oclc doa ypnt i aiio oeriaoi   ai  in iiin , ssiiaeaaataoi  amdrtiar  iongsa"et&ce aoco d deogeri uyumkainmioiro i liot rsdasosea m oai wic eaisl oao oii " s,onolv:iiVh   lgsiia uselyvibhu i
# Epoch 4/50
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.7102 - categorical_crossentropy: 0.7102 - accuracy: 0.5368
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "This "
# This =====|=============================================@============================‘===========================================================================‘================‘================¼=========================================================================================================‘==========================================================================‘============================
# ----- diversity: 0.5
# ----- Generating with seed: "In th"
# In th²—=–==…=ñí=‘=É=ñ[è‘=^=°==[[==||=²=[‘¼==|@==¾==‘==¿||=|—|[¢=²=²===|ë=====ç=+==ô=‘||=‘=[=¾=*[=‘=ó===¼|=‘¾‘==ë|=‘‘‘==—==^¼=–“^‘=|º==²–*¼||=ó|+===–===°=‘¾+==+|¢==²=¼[¾==‘|=[=T=====||=‘===‘é“=°è====…¢+É|‘à===‘|=ñá‘°|á==–=[=^=é===[====[°==‘à====*=“[==“=‘‘=—=‘=è==¼[==[====‘=áé‘|===£É=*=–=|==[ó+‘‘==—=–ô=[@==¼==^=¾=======+“==²ô===[‘==‘…¼“…[è====^¼=@[=[‘|=…=–[==“[^=[“*¿=====@=[==‘=‘==[è=“=*=—+|=í=—=[=====ç[
# ----- diversity: 1.0
# ----- Generating with seed: "It wa"
# It wa@ç¾¾#ö…=|‘¼ççWèá¾^çö|ì‘=x==ç*ì|+‘½—=¼à=‘“+—“=¼¿||ö^½[=½[^‘‘(£ôô^“é[²‘=Uéèà[ñ=‘ô…=°…[=¼¾¼|=à@‘^ô²=[é=—[=|==¢ç²àç==Éº£‘‘é^*|ºü=à‘àüç=|Qà¾|Qñ=|ë=¢=ç…+@²ôºôáíö^…^ô¢ü‘=ç*¿V¢—=°=%@`=[===çóÉô%ì¿²—–=——–èñ*½ó9|¼|ìçí#½áè“É¿£%=¢¾—ñö=‘–¿[º=¿[+‘[==²‘èá=[“‘#í(|ô#6=ó[+[²¾+è=–ñ^|½==á[R@í|=*|¢º“=|%ì|¾£¾=—üà¼²£|+ñë¾º°=¼=ºç—íÉáQ…|‘‘=(+=‘óö£¼[[==[@[“ó…*ë¼|²£à¿=@ô‘^+É=É*=+“ºá[=é…—=¼¼=é[‘%²[^—°+`==0‘²—`[=²¼é‘‘‘¼||^*[$…
# Epoch 5/50
# 10000/10000 [==============================] - 78s 8ms/step - loss: 0.6769 - categorical_crossentropy: 0.6769 - accuracy: 0.6713
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "To ge"
# To ge      i    a           i   aa  e e         a  a        a  a    aa i          e        a               a i    a ia  i                 a      s i     iie sa  a               iaa  ia   i i a ao s   i   i i    e a        , a     a a eii ii   i     e              a      a i i       a   isa   a    i   a      ia i     a   ia aa      s            i     a a               s ae        s a  i           s    i
# ----- diversity: 0.5
# ----- Generating with seed: "Pfoun"
# Pfoun eane h a       s a sa si aai i,s s esrs  eiaeo,a'iaia iw'i   iiriee  ,  'ik ei  i   s   a     ee  oi  ,re eama       t ima iii,isn e nasi  ahis ,n  e ia s ,a   a ,rai a o,em,"o ioeoh ioe,af i   a eea ihes,s   o     siaaa     , ofai  se siia aea o rta uam,a i oo s   a sro   etiiesi;u or   siao    ,i a  i, r  asaii, siia saa,a s s  rs o      s ia aa i  sia i snmas,as, aa oasi isi a  , vseo,,ia-  ai
# ----- diversity: 1.0
# ----- Generating with seed: ""Der "
# "Der  lwoaar s   iooasiVaat-t Fa',aen" n'd.l  cncF-aCsue ia E-r sih eb-st.evoone,finasaimsh eias,iaoetfseio ni"a,,rs, t&iliiiauoon limeaaa,eicsf"if-ims,c-s w eei ihi. eeailaooarressksan ,aiiesaoii  sodawraiio enor,',ocm uiso,sr, nsIpiu,om&ni y,1aisus c,,i a nrt,,osep el i,Aeoi  iirsrtslN )oc,is.Ccmifs)eoo't. et, rn"mntkaousis,oieFda 2uraikidoitOld,ouiR -u  oa; w 'aUi;',ata n"ihi1immsowrtnBseeiss.na , o
# Epoch 6/50
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.6524 - categorical_crossentropy: 0.6524 - accuracy: 0.7876
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "Famou"
# Famou                         a                                                                       i                                                                                           a                 a               i                                    i                           i                                      i                             a                                      i
# ----- diversity: 0.5
# ----- Generating with seed: "In 19"
# In 19 i et       A m    a ,ai  m  e "  a   aa  ia    ala m h s  a    i,          ih e    s aeean  m  m ,i          'a   a          a         a   o   i        a  a           , ,   oa o m         ,,   s      ai                a   a    a    e i i  n       d   a  , a ai  ,i   ,'a   ti    e  eia  , a, i   , aa,ai        i 'd    a o  a   o  a     .  i y  a m   i    i   a       aa  i  i io     ,i       i m  a
# ----- diversity: 1.0
# ----- Generating with seed: "The L"
# The Lo  ,cdaimw   5e )N ,fi; em'a l  oh,, v, d,a  aan   eh), eea aei;ewao  il"i  ah s,  ,i,', mu  iihvo aPay    Eee lo'sIho,i,'a ooei    am ei  hn  iifu  'rltf'cagnecUh-e ;i ;rIhia 'Iinae&eiDw Pj,myaLi as  -'lumh,o,rDf i,Ca)yfoeS 'o inwaiii arh8s ulllz  D ,r l:'  h    "    iAiha)s,c T.s  i  'D'taih hr' oashaas' aeAno nis  r ikaa m ENaist, A  aaa, mdr   a'ri ai sie  iea e"is   elboa),o.  ol %  s   ', h
# Epoch 7/50
# 10000/10000 [==============================] - 88s 9ms/step - loss: 0.6340 - categorical_crossentropy: 0.6340 - accuracy: 0.7778
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "On No"
# On No   """""""" " "" """"""" " """"""""""""""""" "" """"""""""""" """" """""" """"  "  """"""""" " " """ """"""""""""""""""" """"" """""""""""""""""""""""" " """" "  " """ """ """"""""" """ """" """"" """"""""""""""  """"""""""""""""""" """""""""""""""" """""" """ """""  "" """"""" """"""""""" "" """"" """""""" """ " " " """""""""""""" " """""""""""""""""""""""""" """"""""""""""""""""""""""""""" "" "
# ----- diversity: 0.5
# ----- Generating with seed: "Watch"
# Watch     "  ""  "   """  """"" " ",   a" """"""  """ """"  e""""""" "" ""  "   "    "a"""""e "w " ""   """"""a"a""""" """ """" """"" a""" a """i  """  i  """"" "" "",   " "  " """"    "   "" "o"  "" ""    " " "" ""i  e    """"""""" """""""""' "  " """ """"  """ """  """""r  ""  """"a  ee  , " "   "e"o"a   "s""s"""""""ia"" i ""e" "a ""o"   " ,""""t""" a"""s"   """ ""   "e" """"""aa" """"aa"   ""  """ "
# ----- diversity: 1.0
# ----- Generating with seed: "Jerse"
# Jerse,'  rr a,uAi,a '  auanaw'i.,ke e   " y"ap's  a"  hs"  mlirh  an,gii m  nn n le ehhPe, i g '.  aor i').'f,t'',coe y,1iEa.osnt.A NS m  l i':hwgslu irae''emdma:kaM   "s  , ",myaghsh'ohs.a o0 ,' 'r ulsa,i Css i,) 4r s ;. s,  ehda lr   :'i    rg' seRw.  umhshi,    u e  '" s"i"  ”ogh'i"eI"a m,ai (3 iia  Dai e'eaio,r;,e  "l "L".l  ! '?r "eba""neoyl  ,,  )   ae"""l"  iae .os gaFn n''   " ra""nma,to.w ,E'c
# Epoch 8/50
# 10000/10000 [==============================] - 87s 9ms/step - loss: 0.6193 - categorical_crossentropy: 0.6193 - accuracy: 0.7341
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "Shake"
# Shake    """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""" """""""""""""""""""""""" """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""" """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# ----- diversity: 0.5
# ----- Generating with seed: "Alpha"
# Alpha   "" o""  ' "o"" """ """ """""""""""""""" "" """ """""""""""""" """"""""""""""""""""""""""""""""i"""""""""""""""""""""""""""""""a"""""""""  """""""""""""""""""""""""""""a"""""""""""""""""""""""""" "" "" "" """" "" "" """""" ""s"""""""""" """ """"""""""""" """ """"" """""""""  """" """""""""" """""""" """"   " """""""" """"""""""" """""""" """"""" """""""""""""""" """"""""" """""""""""""" """"""""
# ----- diversity: 1.0
# ----- Generating with seed: "Gates"
# Gates',l :- ,i' XaTP i8re s s)' 1ha'hu''l' r e cm 'bc me'"hj t  _" r ""e,""s;h""'  ," """”crw"a 's .dae s.hn,n , k "w"pIm   .u"""s""si "ae "a",m" 'w're'  ' "a """o"a h o- E  o(   ,  """ "s"s"h"  )aou,kesTd'' h a':    a" sgi"A'.,o'Hys ""! ","" "o "," ", "iN "m  """""" g """ t""""" " s .h': '"" a a"" i   """s i"""-r""  - mrk'  a'd , 'in') a  ,,kercEho 7 :vs tis '' ah .] 'e,sMaH '- , :a ,g[m,a!so, aba' h
# Epoch 9/50
# 10000/10000 [==============================] - 78s 8ms/step - loss: 0.6077 - categorical_crossentropy: 0.6077 - accuracy: 0.7271
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "All o"
# All o   """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# ----- diversity: 0.5
# ----- Generating with seed: "These"
# These             o  """""" " """" """""""" """"""""o""   ""e"""""""""a" """"i" "" """"""""i ""i  """""""""""" """"""""a"""""""""""""" """"""""""""e """a""""""""""""""""""""""" ""i"""""""""""""""""" " """"""""""""" """""""""""""""" s""""""""""" " "" """" """"""""""" """"""h""""""""""""""""""""""""" """""""""""""""" "" """""""""""""""""""""""""  """"a""""""" "" """""""""""""" """"" """" """"""""""""""""
# ----- diversity: 1.0
# ----- Generating with seed: "Carri"
# Carrie k,rewa t'a'2.i )   i' Ce  ;h  h cRsi') ewcS i m,ao osee-ko,rflo ,  b   ,,  7   h'  -emuiu eo-,ae si( ,ak, -ek s iH eiUeS  ' E ei   h     ,,,tBans':  o sa?)  ' ;sel,,aal,C ds ae,iLask'F  ) I a  ee  c"shM;"   soNis  :A .,  -E    bo e     ',vnF e p a  'lr)e Fm     k  or as b ;i ,Ee2y a,"baA'  e'""o k" H  usO ,a  t ious f s  , R,Ato i ssE'U.   E''s'ai  r  ;, sV  h  ? g   as  R,ie i.uiaas s,s  ,'w rc
# Epoch 10/50
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.5986 - categorical_crossentropy: 0.5986 - accuracy: 0.7247
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "1965'"
# 1965'                        ,
# ----- diversity: 0.5
# ----- Generating with seed: "You'v"
# You'v  ,   s        s a            ,a     ,                             ,e                               s         ,  m    , ,wa                 ,,     a       ,,       ,       ,        a          a a    ,         - ,         e       )       , ,            o,          ,,,          ,                  i,        as       O                c ,          , ,            m ,           ,      ,       '  " """
# ----- diversity: 1.0
# ----- Generating with seed: "In 20"
# In 20,s  s , ,.e-e )aUmo  a  m     ,,,,."ia a )a'aae )ouc a  ,,., cm.  n  aoa,'  rl,,ua-a ,r '( ma9a,   a'   t ,s mf ')',to,sui  ,E  ano  ,   e ,  a i "ap""ht  p,,(m  ) )u, i:as  ,n]b iu  iF:  ait i  bc  '  Tual o k  E's,,)' G, u&' sip   aaA c       o  w,e ,,r:,uasih g s     , ih e    ,   .af L  rai,.,   s  leu.,iuwf (s  tz acg r  tio  b t  a   , t   u e ca ,) -ami "s i""u" '),e, m aa  ,ra aa o,e o b!
# Epoch 11/50
# 10000/10000 [==============================] - 102s 10ms/step - loss: 0.5902 - categorical_crossentropy: 0.5902 - accuracy: 0.7323
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "The A"
# The A
# ----- diversity: 0.5
# ----- Generating with seed: "Carey"
# Carey      s a   ,"""" " "m"""""" """ """ "" "" """ "  """"" "e """" """ """"""n" "o    " "",""""""" "a""""""" " """ " "" s""""i """"   """"" " ,"" """""  """""  """ ""e  """y" """" se  s,        ,""""i"" """"" """""" """""""""" """"   """"""""  """""""" """ "" " ""  """y "" """"" """""" """" """""  " """ """l"" e  """ "" """ """" "" ""    """ ""  ""s"  """ " "  "  "  """""""""   """" """i"""  " """"""
# ----- diversity: 1.0
# ----- Generating with seed: "Sylvi"
# Sylvi',,a " e  "r"" u i"  ,iad2o a'  iaao  '” ""os""  ,rs", ,  h  f  s,,:s)"C wc a . """y o "r ". i. oae ee -  C "e"" !,ms rc,a,i, e a  or e,i,u  o s4 s  a:e  ai c,   e)u,  sh,kl         ,"   "es"" Ushw  ,"iyo"r a "eaao?eb y     ;ia s t ' asae rn so hclaa. arhas, ,R "e "  "i".i""'"ee eo .e  i:   Ch1,r ' "a"" 's o  ckr K e.a ast, seas'ie ,a"e  )"   'i""or si" sSr, 4issim bai-hihs  s ,s ","""b?sgw " "g"m
# Epoch 12/50
# 10000/10000 [==============================] - 88s 9ms/step - loss: 0.5836 - categorical_crossentropy: 0.5836 - accuracy: 0.7538
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "Some "
# Some                                                                                            s                                                                                                                                                                                                                           a                  , """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# ----- diversity: 0.5
# ----- Generating with seed: "He st"
# He st    a  ,""e""""""""""""""" """""""a"" """"""""""""""" """""""""""""""""""""""""""""""""""""""""""""""""e"""a"i""""""""""" """""""""""""""""""""""e"""""""""""""""""""""""""""""""""""""""""""""""""""""""" """""""""""""""""""""""""""""""""""""""".""""""""""""""""""""""""""""""a""""""""s""""""""""""""""""""a"""  "e """"""""""""""""""""" """"" """"""""""""""""""""e""y"""" """"""""""""""""""""""" """ ""
# ----- diversity: 1.0
# ----- Generating with seed: "Jeded"
# Jeded c n) ah,F 'p,iceama. is  -no)'ai)saeguca i ma'u  )ki"ha,"? .”a ""u""s"heai"to) "?" e "ib su  as-wia,a sosa,aos :a  ii'w  b sa,w )hdi, ro i ,, i a,uav&a as u,)sSks f) )a / ! ,s ""e""u"o""i(se"iw,vs;c'at   ,i s" ,"emysa hoi e  h uu,aac o,Gtat&,i  ,r e"s"et"!uoepae, ,  a s  kgum a: ,""ia "" .!i )  u  sab ,aasis,ooei  l al l'an: ae g'""" """"e"" a " m"    sice, ' a     m-o ,-mae  sasanuiem """""oosu;
# Epoch 13/50
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.5778 - categorical_crossentropy: 0.5778 - accuracy: 0.7412
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "These"
# These                                                                                                                                                                                                                                                                                   a               s
# ----- diversity: 0.5
# ----- Generating with seed: "This "
# This  as,e   s a         e          aae    h     s,  , , ,    ss  o e      s   s  s    am    s             ,a s- s sl            "" ""a"i"ea"  sa        s'r "o"""e  """r"""" """"""     ea    ,   a  s  a r              e     aa as     a  i  a      ,,s   ss      ,s    e  ,a      )s a     s  e c ,   ,a      s  , a   ,es           saes   se  e s s   ,         a  s   s ,  s,  sa , m a s            i    ,
# ----- diversity: 1.0
# ----- Generating with seed: "Accor"
# Accor u'oy iwhi,i ln mh'ua  e ,aa,,"Dun-!,e; nh),eS,ss'sA)o-s ,,  ,a  , ,shayso'e.i d ,eep u'ue 4h wh  hsui  s  e kt  a! c Eaio"ana-era ueshai eCs  aiamas eE , s--t,aas) a S!  """a.sesssuNw)i a n H.u ')au,ao-osse,,l  inyTssbe 'wo c u n sEiai-enes )u  ol m ws-,,u)seokible  h',s, u nahk se  ssr e-uwi ,msA - r  ,,a ,w . "om"aI k"ie , ,h  ""r, ia b)o:  ,)    uai s ss"  r  oa a utumas-ec "la"er, o-ssssee ,
# Epoch 14/50
# 10000/10000 [==============================] - 86s 9ms/step - loss: 0.5725 - categorical_crossentropy: 0.5725 - accuracy: 0.7408
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "Colle"
# Colle                                                                                                                                                                                                                                     , """""""""""" """""" """"""""" """""""""""""""""""""" """"""""""""""""""""""""""""""""""""" """""""""""" """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# ----- diversity: 0.5
# ----- Generating with seed: "Besid"
# Besid) ,                , " """"""""" "" ""  ""   """" " "" """"""""""""""  """""""""""""""  "" "" e  """ """" " """ "f"""""  """"" """"""  " """  """"" ""   ""  """" "" """"e""  '"s""""""i""e" """ """"" """"  "" "","""" ",""""" " """ """ """ " """ """ " "s"  " """"  ""  """"""""" "" """s"""""" "" ae"   s             s       '  """ """" "   """"""  """" """" " """ """""""  "" " """"""""" "" """""  """"
# ----- diversity: 1.0
# ----- Generating with seed: "In a "
# In a iasf"s  s""  ," """to""o ua",  ht ,,  &  '  ,  " i"a """' "" ' r""  ;"" -""eO""" ,"""   "" "s l.g e sbe H  o s,,Us  ienc , 'a, ,as  n'l, ra s, it  msiw-ais 's  " " " " ;"" "aus" u s" s  ""i "u,"" X /    ,,"  av t )   s s l'k,as am so   :a  ,, ""," "" s "s)e"m , "r "" "o """s""  a"" "s i"    B  i s )br 'a; .'   e-''na,a"e sue  'r'"","    b ' ')a-mr   :,$[       coa   E  e,,a     r ak    , r:  ,a,",
# Epoch 15/50
# 10000/10000 [==============================] - 85s 9ms/step - loss: 0.5681 - categorical_crossentropy: 0.5681 - accuracy: 0.7604
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "For t"
# For t
# ----- diversity: 0.5
# ----- Generating with seed: "The 1"
# The 1                       ,"""""" "a""" """""""""" " ""  """"""""" """s"""""""" "" """ """"" """""" "" """" """""""a"" """""" " ,"""""" " "" ""  """"   """""""e""   "" """ """" "" i""""" """" "" ""i"""""""""" """"""ee"    """ """" """""" """""" """ "e""""""""""""" """""" """"  """""""""""""""  """""" """m"n""   """""""""""""""""" """"""""" " "" ""  """" """"""""" "" """"""""""""  """"" """"""a"""  ""
# ----- diversity: 1.0
# ----- Generating with seed: "This "
# This ,o ao:   a ,a " ""u""aUe",   "a"   .oa msa, "" e""""" """""v"n" w)u"a   ""s u"s t "pl h" hss),,    a,Emi,s o  .: ! )  .,t"s "i"g"""o" ,a ""i"""'",  """ a""" c,aarhfa o ur rsi   y  cm  e i , """i)"m ,m:"""ws!"/ ") "ia "a bw aiu o]; s "a "" ae""a &"  si"f"' "oo rs ,  ,"""e"" o ) ' l E' a)    ,a""a o" s s"osurs  a  e  iaa )e       ]  i s),,u aao c"' os",r d",;  e isi,',s ,"m"ei ,iio msl  e a,, ) s  t
# Epoch 16/50
# 10000/10000 [==============================] - 85s 9ms/step - loss: 0.5640 - categorical_crossentropy: 0.5640 - accuracy: 0.7386
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "1996'"
# 1996'  """""""""" """"""""""" """""""""""""""""""""""""""""" """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""" """"""""""" """""""""""""""""" "" """"""""""""""""""""""""""""""""""""""""""" """""" """"""""""""""""""""" """"""""""""" """""""""""""""""" "" """"""""""""""""e""""""""" """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""" """"" """"""""""""""""""""""""
# ----- diversity: 0.5
# ----- Generating with seed: "The 3"
# The 3    a      ua       a-aak o    e a  r  s    is      aa    a a  ae   s e ai     ma i a a a  o i"""""""" """"e""  e "a"""  eio      e    o a       a.)     -e      s   a        ei , e i          c a m  ioam)           h   a   m a s  a a a a   e,  u       a a '   s a    i ,ih  '"a u" a  """ ee"    esa     . i m l a    a a ,s   a  a s oeam a       s . seoo)    aaa   , e""" a  ""a """""""""""oa  """"o""
# ----- diversity: 1.0
# ----- Generating with seed: "Examp"
# Examp,() aae.uk,'e  ,o "i i"a t"sei m -aoa.sh: os "i " e sesaif)i)ba iae a,ii u  usmo saiagas  ,; o eoawun ,mh,r tu ),fEeasia,t  g   at:; .w.)' a 'uia o  s aa eeit 'ye   ue m:)s:[[ea$ ea-e, e  , "i.""oia": o, ,t "'i ae"u" )  m,'s aloa afm raia  , a"o"aau,",sto  koemmho ) a ,seu hahloea ( )satsh " "d"esu "asa a iss sawaaos   s  .,am  i  thiid es  '"   csmvsa ha saag". ,ea,a- 'e , smaha))a,- i k'aaos , '
# Epoch 17/50
# 10000/10000 [==============================] - 87s 9ms/step - loss: 0.5603 - categorical_crossentropy: 0.5603 - accuracy: 0.7563
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "A tea"
# A tea                                                                                                                                                                                          a      a                                                                    a
# ----- diversity: 0.5
# ----- Generating with seed: "This "
# This   ,  i ,        a   i    a          a    a  a              ,  a u        a   s             ia ,   ,  a i   a   s ,,      a          ,                        u    ua  -         a                 , s %    aa ai     a  m e   ,    a           a   a         a s-  ,  ,   )a,            ,    a      ,  ,     s  a   ,a   ,         a      i  aa             a    , , a                 ui   aa a a  f         a
# ----- diversity: 1.0
# ----- Generating with seed: "Prece"
# Prece  oa  b-,'us),u",a i% o'- , ;,,,  ).a a -r, o  m n ,m,ie:-  ,s, ag,sa s m"   i,i  s,, rbi, aa)um       ,au  e  ' ,  s aba,s,'s),:i asm h,ii l ma ah aOv ;ya ai s   a o ul s s,ta    :ir  s,'  of, e s' a'"%hm"o  u g-a a ane u aa a  ' rs c a&i,  s a  f iu , aC),, a.ssacfe,s 'emaah,;  si'aua ,, ;ia oa   , : ; s'u'u, a- u,a- ;,e,f,a   a(a-s'),,," i ,  ,r        a'i  eoh)u ,  ( )a )u ,ua   )au;ree s ,  '
# Epoch 18/50
# 10000/10000 [==============================] - 89s 9ms/step - loss: 0.5571 - categorical_crossentropy: 0.5571 - accuracy: 0.7565
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "The l"
# The l     a   a                                                                                    a                                                                                                                   a                                                  ,                                a           a                                        a             a               a
# ----- diversity: 0.5
# ----- Generating with seed: "In a "
# In a )' )          a i)s su    aau  aa     ''   mi  s      a , , a   a  ' se    a  i  )-   a    )aa  ,:    'a)) )   a     a  aaa   aa c a, u i )  i   'a   e,   ,  ,       aik a  'k        s a          a a     ,i  ',"""[" "m""     a   f' o)  i  a    a)a     au  )   ai : a                 ia e ,-   a a  i   )  au'  '   ,)  aa a  ia        e   a    aa    eas  t        a    aaa  iia    i s  )se a  sus
# ----- diversity: 1.0
# ----- Generating with seed: "This "
# This sae : ai, ) . shk)is,)) efafs  u d '::as"d)& , m''-a'h,s'   u  wa,''s's" ) iIw e'af;sam   &) , mi v-  s'u'm,du'ki .'a,aj i)a)a eeu sa kl a a,-))v )cm  ittaa's sos: e . D'' ,cios's";)s) a , - twie)o ''oni  ,s' ):e,aaos,'e---esi u,,  eNa: 'eu ,J  ,,?"ud!$ae)' h t s'a ""] ""wco",y a"a""sa"o oi" n 'a i sl,) a'a  )'u,csc,suB 'huo'',o. " " "'"' "" i,omec) 'e ')  )   )i   r o'  ai,a,o'a e  aaa.:aiuo ayc
# Epoch 19/50
# 10000/10000 [==============================] - 100s 10ms/step - loss: 0.5545 - categorical_crossentropy: 0.5545 - accuracy: 0.7680
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "AKA b"
# AKA b
# ----- diversity: 0.5
# ----- Generating with seed: "A U. "
# A U.    ,     a s    )        a ,                s          ',!$ %  s ,   a ,   o        c  aae       '  % ,      a  a     ,  a       ,      s  , $      ,    a     ,                ,  , “ ,         s s   ,        s    ese          ' st    ,, %a              ss,  a            , s% '   )    '  %   s       a    a  s               ,          s  ' %     ,  , “ ,        s       s       ,                a
# ----- diversity: 1.0
# ----- Generating with seed: "Thoug"
# Thoug, ,a);   ) ' '"-  r%,  '%%%   '))'e ea, a'aia a  m (sa ,a sai ., n,"   ), tahs'e g, o'i  ( )s, , s Y%      a)ty  s   ma  :,a  s )'  sss, ')o e s  ,,aa."),,))$s  "%" e' q e),,s, a r't,sh' )-s  s )e, s i (a sc.,,,v ,.s  o a i o      ),'  :,  ,,rs "l%%%y i o-sfe  '$%, os ' ,,f, las  s : al!,,See -     )'s e,oiars s,   , ,thaia s ss's  im' as ya s,     s aa )o s; ,a s uiu"   )e -,ha  s sa  ;'l,s   , ,
# Epoch 20/50
# 10000/10000 [==============================] - 101s 10ms/step - loss: 0.5514 - categorical_crossentropy: 0.5514 - accuracy: 0.7548
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "When "
# When     aa  a a   aaa        a       a  a         a     a           e      as a a  i     a aa a    a   a     aa                 a a  a     a     a    a   aa         a     aa   a     aa a    a       aa         a aaae    aaa e           a a  a      a     a   a  a a a     aaa     a a  ae a a aaea  a      a   a  aa a  e   a  a    a aa       a          aaa a  a    a  e      aaaa a  aa    aa   a  a    aaa
# ----- diversity: 0.5
# ----- Generating with seed: "Once "
# Once  aa ee   a  eugaa a a aa a em  ae  a  a   am a a    a sa   aaaa eaaa ea im)iias  eae e a'sii eia m a s sa  a ai, m aa u aa m us   aaaea maaaa aae e sa u aesaaia aii   aiaia sau e  aeoeasa   ai  aa i  eeaa iia s aia mias'  a    iia  aaaao a  aa eaaaai   ai o  aaaie      e'u u a a i a m  e  iasae  ue  amaai u    ua iatsa      u aa   aae aua a u i a ooaes aeaa e  aa om amuio   a a a  u, i   )i eae oa
# ----- diversity: 1.0
# ----- Generating with seed: "The L"
# The Le a",ueseoi,  haeemama -iieha uu) aaeu s    iu:ai,eua  ea msei,ic w auwm,i  a a ae' oaeuae'aaa  a)i d.u ii i'saa e oo ehiaai iemaua;so.s:o ri a]im   i aauw-i ;  m)smeumuaaai  u ,oeloa e ,siuao'aa uag epoisa i oaimoa-as aa,iaeuaea  iamai    tva )m  masu Geaahu' a e,'sg a aa;ai s r -e'i ae au aas,-; ommasss ls u sue aasm  "pi ;wue so saea.  uaa a  ear iiau si uhar s   kuoauu a cau,hiea aie  a aa o '
# Epoch 21/50
# 10000/10000 [==============================] - 97s 10ms/step - loss: 0.5491 - categorical_crossentropy: 0.5491 - accuracy: 0.7263
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "The B"
# The B                                                      ,                                                                                                                                                  a
# ----- diversity: 0.5
# ----- Generating with seed: "Okay,"
# Okay,as         aa         ss   ,         s       a    a,             a,          a a    ,sa"        a ,     s s     a   ia ' a  a ,  u      s  ,  a  o  a  ,         ,e      ,   a,a   a     s    ,        a, a  ' ,    a    a    ,,          a,          ,i " " "e""   " "   """"e "" a""     h , s   a   u  a a              eaa a  ,              a   h       '         s   a  e m             ,      a a       a
# ----- diversity: 1.0
# ----- Generating with seed: "City "
# City  i   - so' a) o saa,s  a as',aa , i   iaaa   oyass s,fs, sd :ohi i Ca'i'  , a" ai iei;l  s'a" ) e i.i   aa e 'h:i as  fm .i a,a  i'   ;  sisb  a  u, H 'ua " " l"   ,, i   'ms a, '    2ui i2)iT  o:a  a,e'ao . ) ae n,  uer    , ,:a m eEea.siia, i,au,sia Ia) ae   she. s Uc  ,im" ai)"y )  is e ,e's)ai -    , hialrei ahi ,u) ai sN a-''u aei  i-s aa    a,o a )osfa a, e b ,aoencu ia ek,a eu,ufn     o, 'k
# Epoch 22/50
# 10000/10000 [==============================] - 94s 9ms/step - loss: 0.5466 - categorical_crossentropy: 0.5466 - accuracy: 0.7237
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "She w"
# She w """""""""""""""""""""""""""""""""""""""""""""""""" """"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""   """"" """"""""""""""""""" """""""" """""""""""""""""" """"""""""""""""""""""""""""""""""""""""""""""""""""" """""""""""""""""""""""""""""
# ----- diversity: 0.5
# ----- Generating with seed: "This "
# This , """"""""""""""""""""aa" """ "" a"""s"""", "  " """"""""""""""""  i""   " """""a,""""""""a"""o "   """ """""""a" i"   aa             a         a    a  a         ,"""""a"o"e ""  """""a """ i   a    a , a"""""" "e""o" " """"e"i""  a""""ae"""""""    ""a" a"    "" "a"' """""" "  i"" a "a""""""""""" """ " a""""""u""   e"o""  a a e         i                 aa        a   a    a  )            a  a
# ----- diversity: 1.0
# ----- Generating with seed: "When "
# When  a  i z")a;:u   ,ki asa )i  palaa eog    ," "  .[[  ";.s ""m""""  l""a     o)a   .a u  m 's  h    sake eah  oi y     geu D oa aoc lus  a  '""e"e, eu '  eL h h)aku  i   aw' aeieaa sum-u    ,eesm( zm oaao   asoi,iaca,    .'N"y". areo n  -ss,   eas aoasha't  as  o "mr",   !ai ! aunsa,u  "i"a.s,eu,l e     '""!otoaiaus a a -oa. l ) ,y  e   '  "a"" e iu  ,e i uak ,so  iae'ki, ; oa  o ,ai 'u "i" e e"" "a
# Epoch 23/50
# 10000/10000 [==============================] - 97s 10ms/step - loss: 0.5446 - categorical_crossentropy: 0.5446 - accuracy: 0.6431
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "Yeah,"
# Yeah,       a                 a       a       a         a              a                                         a              a    a                a                             a   a                     a          a                                                                                 a           a      a        a a         a      i         a                            a        a       a
# ----- diversity: 0.5
# ----- Generating with seed: "Linco"
# Lincooa     g a   e  e aai  a-        ,         a         e-a           a a     aa    i saaa a     a a  a      a  ia a  aa a  a    am     u a      aie a     a  a o a  a u a  a  e  a  aei , o a  aa    a aa      ih    a  aa ai a   a a   ama  a aa  saa    a  i a , a"""" "        sa   a sa o   i ,o o a   a ia  a a        a i  ,          aaaa       uaa    a   ,   i    maa aa a        i a   ia,a,  aa  a
# ----- diversity: 1.0
# ----- Generating with seed: "It wa"
# It wa auma    s  afa'i),ijes  ia aal ) adur'aseda  e'm ,, dse ea  a si  ,aase,:e-5iaa      a)oa  ,,a ei i h ,t a-,uieoas ai -o ,aa' a eo  o no a, aa araah,a eo a i i u  "p"busu" uh "ai,  gas ,oo, we"a  r"pgia"t   'i 'i,)aariai.larmk,a  e 'wadaafuaogas  ao,ia  i aomaiu'rrh 's oaaue,ua',z  mho ua ,a e,ia, w o "a&"s i""i", amoata )o o ;auae,a  u    ao  e  a -aa   abmya,h rksi,iso fua wa   '-  w,,ao.'som,
# Epoch 24/50
# 10000/10000 [==============================] - 93s 9ms/step - loss: 0.5427 - categorical_crossentropy: 0.5427 - accuracy: 0.7256
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "Origi"
# Origi      aaa a  a  aaaa   a    a i  i  a  a  a    aa a       a      aa  a    a a aaa     a  a      a a  a  a     a  aa   ia a       aaaa a     a      aaaaa a a   aaa    a   ia     i      a   aa  i         a   aaa  aa           i ai      a      i i  iaau a   a a      a  aa a      aaa      a aa a    a       a   i    a     a  a    aa   a      a   ai  a    a  aaia   aaa    a     a   aiaa a i     a aa
# ----- diversity: 0.5
# ----- Generating with seed: "Steve"
# Steve a a a  e aa mi  e ea aai aa ma  i i  aa  ai   iuiaaa eaama seia iiaaa aaaa ma m ae  ah   ua aam i  a ea aio aaiaai i  a a  a aa aaua-uhaaa aea oi ae i  u ih imiaaeiiaa i auaa" uaa"  aiuai   aa ) s  a   ai e  ahka i   ia au e i h,i  aeamaeiu iaa ee aiaiaaaii  is m  aaaasai  ea  ai a  aaaa maaaa   t  a aaueie u   ae  a ie a a     ami ae  s ai   ii    a a aia   as  e aeaaa emiaoii  a siiia a    ai
# ----- diversity: 1.0
# ----- Generating with seed: "On Ap"
# On Ap]u-iaa,ahh uoi ei ,hg,tfaa a ' oo muh)o  e  iho yte w as,haiaim,uiee ue   ,i"oa,, ieeessh smao  wmata ,a auoaaiha a-  'ageiuu o o  "r"i" a i" o,,ua ho-uo):saso aa e ae'iiiuaai,iaahma amt  eou l aiu e aiis  eieiiha mha l   a isswseoi)asd'ma   omio!ewlaiek,anvima ahhiae rahaam 's"a"I " """"i ""o""cma"aiksiu aha,o' moh na   aaaae] reeaeazouimmi aiis e sie'ehf   ahau ac ?i -moea  kibr fmii;  ie ia)a ,
# Epoch 25/50
# 10000/10000 [==============================] - 93s 9ms/step - loss: 0.5407 - categorical_crossentropy: 0.5407 - accuracy: 0.7086
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "The b"
# The b                                                                                                                                                                                                                                     i
# ----- diversity: 0.5
# ----- Generating with seed: "Door,"
# Door,a e   ae,  a     o       a       ii      u  a           ,       a     a    , i   o     i               ,ei aa      'ua's       o   s                a      i a    u s        ,  , a    ,        ),i      i    ,, i  f) i     ,      i i    ia  a a  aa    a,        s    a a      a         ,   a    ,  e, s    u i       'i   ai  s ia,      i  ,' """"""""""""" "   i     i   s         ,   s o,, e a a  s
# ----- diversity: 1.0
# ----- Generating with seed: "The d"
# The ds u  aae):   ),, , i e,,ss    ,--a  i,,' kii i!   a mu]al     u; eu ,ae  i  -i,   ,i  y&i',-""  l.'em,.,at .,,l-s' d  iu ,a , i,esieos  " ifs,y  k  . '     ) i   aio- ,om s,eu:ii)  i se , r -   -  s,sa   o,a aeiei,  ei) e-  h n id    i,a,'tbab  i e   m;ea i,   s  )),;) ,i, w,s -    ]aeosa  ss-hahi  Ch  Gaiufumf, ete e oaa  hcAwi  i ' a s,' ao i  s  , i,,tgiiokfoi e,,ai  ya;,r so o,iso a,!  'l'  :$
# Epoch 26/50
# 10000/10000 [==============================] - 93s 9ms/step - loss: 0.5389 - categorical_crossentropy: 0.5389 - accuracy: 0.7464
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "Marsh"
# Marsh                                                                                                                                            a
# ----- diversity: 0.5
# ----- Generating with seed: "This "
# This    e     a      s     ae                     a  ,          a       ei      s  a  '        a   a     a  , "" "  """""""""""  """""" i  "" "  "  """"s" "  " """""""""""""""""""""""""""""""""""""""" "" """" """"a  "a" """" """ " """"" ""  """"  "  " ""e "" """ """   "" "y" """"""""""""""""a"""""   ""   "a"""""""""""s "  """"""" """" a"?i, """"""""""""""""""""""""""""""""""""""" " ""    """"""""""""""
# ----- diversity: 1.0
# ----- Generating with seed: "The c"
# The c"   m" e'me'   ia  .a i )  ,eie,ai iahi'  ae  ,im" -;i  ,:as a    amar,k , ss",  2a )    e' i  '  e p lo )uaaas  e,soa:   u  asej, ' ai assi'a u i a' ',;h   s  ,a ""e" " et "e e ""i" ?   "i  "" a"iihe"s, m    i i  u i sea) t h    ,""s """"e,"d"a """iii, i) ,    ".""e"""" "m: ,"i" "":“ $"o "es"s'e s  ,e"iaeh ia ' '“m"i“" a  "'y ,ae du     o a  mswsa a   ,  e"  "o.,   a?y a,ea l  ac   u     u , e -
# Epoch 27/50
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.5372 - categorical_crossentropy: 0.5372 - accuracy: 0.7338
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: "This "
# This  a       a    aaa         a   a       aa   a               a             a       a a a   a      a a                  a      a            a   a       a                  a       a a   a    a    a      a   a aa   a     a            aa   a  a a   aa                    a     a  aaa        a   a    a                 a   a    a             aa       a                a  a     aa      a      aa   a a    a
# ----- diversity: 0.5
# ----- Generating with seed: "In Ap"
# In Apea a a aia  a  ,i  ea    a         ,   aa      a  al   a  uaaia a a   )  a aa a  a i a   i  i    a     ) s a)aiei i a  aaaiio  a,a, a  iiaaa,e   l  as aaa    i  a,   k ay  ai   aa a   a, a aa a    a aa  a   a  , aa    aa, a   a ai  aee  s    aa     ia ai     io a   a  i  aaaa iu a      e   a  au   ia'a a   a a     aa    a a a i 'ias       aa uei     a'a    ao a    a i a   a a    a ae  au a  ai e
# ----- diversity: 1.0
# ----- Generating with seed: "The f"
# The f  a) g  a) muo  ieih  a:yesl'- yama e aaaaemag))a a, aa'a)ai,a .eimoawm ) a oemea)a io ,-la aa! N) aae aae?aa;o[aaaiy-iieke)aaa  a )  ),y-aa a   a mca "a%"", vaa'iasvisr! ;m ai;a  e  '?-g h,eo,a  )  ei u; a  avai  ai ffar'u   h,aak a .eud,iaaaa .,o a-a o -'''ae )eia a aa   s )o a,ia ;sa   'ei-aa.) a,e,  iit ao 'ia aba ,i)c  gioa gmh  ia  s  )h e :a    iauau,sa  miaa' oacai'  muil a.mam  il  a  'st
# Epoch 28/50
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.5366 - categorical_crossentropy: 0.5366 - accuracy: 0.7417
#
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ----- Generating with seed: ""When"
# "When" aa  a                 a      a    a  a      a      a                                               aa  a     a         a  a     a     aa                     a   a   a                                           a  a a      a       aa   a        a  a      a  a                 a                  a          a a      a                     a            a aa   a a                               a
# ----- diversity: 0.5
# ----- Generating with seed: "Perta"
# Perta a 'a  a maai a  a   a aa aa a  a a a au a   ae a     a ,   a     a aaa  ai  , a  aae   aa  a ea a   i a   aa a       i m  a    aia" o a  ga  i i  a a   eaeim a i  a    e)msa aa aaaaaea  a aa aag  i    aa i a a      aa  a a  ,   a  a        a  i a   aa      o  oe  iia haaao a a      a  a   ia   a    aimi        aa  e e    '“"$"   e"o "e i " oy " e "e""""" "  """""  " """" a  "     aea a     i  a a
# ----- diversity: 1.0
# ----- Generating with seed: "Kate "
# Kate  a m-i    )'e ae)amaii'k' ycs , 'aaaas o,e!a-ha ekaha    umaa  ,),e iiaa ts a )a a,ahaisma a"e a,""ey y":,a o ea iaa ,amg au ia '  wa  sami'    aa   aao asm svam oa  a w i eia e,, ahoa )icoeei'saki,asemh ea  o )o- “""Iio" eai"ai  o )aeasi as a  saiaa ,i o  aaoa)q ua!mh  saaa hmaia hi)w)y   isa  aa ta)i) ee,ii s ia,oa spaw ))a:a-e   smie 'as ywevihh  )  aa a'a ''i “"om"i -, eg il a pa ue  ieeo-  mh
# Epoch 29/50
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.5343 - categorical_crossentropy: 0.5343 - accuracy: 0.7480
#
# ----- Generating text after Epoch: 28
# ----- diversity: 0.2
# ----- Generating with seed: "He wr"
# He wr                                                                                                    a          a                                                                                                                                       a                                                           a                                              a                                a
# ----- diversity: 0.5
# ----- Generating with seed: "In 17"
# In 17        a  maa a   u i  m        t m   musio      k ae  , u",t  "e" i, ""   “"e"    “   ""$_ "" u "s"    “ ""$“  “             a    ,$a  $    “ ""$“"" " ""[$    “  si            a  a i   mai  ) a     a a  a aai ia  a,saaa        a  a m m     a    a    i ,o a    aa a  a s     a    e   i,i   “""   “ "s   " e        ' $  a  i a     ia  a  m as       u a      o  , “       ,$ a     e      a  i     a
# ----- diversity: 1.0
# ----- Generating with seed: "In 19"
# In 19),mamo o hm e ) -eu aa s  ;ha a"usy cca,)si ie - m  u bi  -a m:e,a   '""""“ ")$$““a;a, ao  oa l     n',,)-aa eium,st miim i   iimi  oca,    “m$!)a a taa ir su sea" i  “ i“o e $amy asasaa"us,v“"m a,""h "s"e"ee$,$ aa ha,i  m am),)t ie'suoee,"wwu e e  i-e    w aiim i).i'iri)   ,  i ph a, a eao a uu ,o;,) )a )a , s"s ae  ',$ma, ,nu,w m , $ a  am-a '  siups ,a u tsiaa, i-ai toi   ss' efsae,oim  -e)mi m
# Epoch 30/50
# 10000/10000 [==============================] - 92s 9ms/step - loss: 0.5337 - categorical_crossentropy: 0.5337 - accuracy: 0.6853
#
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: "This "
# This      a  a     a   a         a   a      a         aa           a aa    aa  a     a a           , "  "" "" ""   """  """" " " " "" "" "" "" "" "" """""a "" "" "" "" "" "" "" "" "" "" "" "" " "" "" "" "" "" "" "" ""   """"""""""""" " "" "" "" "" "" "" "" "" "" "" ""   """" "" """"""""""""""""""""""""""""""""""""""" " ""       a       ,    "   """""" " "   "   """ "" "" "" "" "" "" " "" "" ""   e"
# ----- diversity: 0.5
# ----- Generating with seed: "A Mrs"
# A Mrs   w uie   a     iop a aaa  aaaa     eae) a   a   a '       am a-h a  aia a a   amu    a,  a e ,a  ak   'aa   aha,a a aa ia  a m  a   i a ai' wa   aa a    aaaa  'e a  a    a aoo  aaaa   a aaa sam   'a oi   aam aa  u   a)  a  ua, aah a   aiem ae, aaoae'o   ai,   , ""m e " "", " " ""a  e  a       a,  o ,    "" a" aa  o a       e   o a a, hua        , e ai,ooa,aa a,h     ama a m,  , a"a   "o"   aaa ,
# ----- diversity: 1.0
# ----- Generating with seed: "Legen"
# Legenu mmeotsneb  : ,?oa 'ai )?' a'h,a'ota' a ,a,oaw ,aiw aaakh     'g)cu a lo    -'"" " "ei)euk o eagomm an ,yik"au  guoo ,aaiea u -, )a a a! av  oi, ai i ms   a   "i t" , ,"u l  a  :a u)la'uaasiauos ,a )  .  s  uo'", .h eiao ,s)ico,  ae, e uaiau a,aiaa) a):a mi'' ,hah u)i  eur- iam) , f  aeu   i-,a 'e a u  u hhi-ya s a a,m,  ,"e)'I uiams ,&aoaae imo' aw oea ),o'iayaoaia-e- koiuaesa,  uiiam mamaui, ),
# Epoch 31/50
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.5321 - categorical_crossentropy: 0.5321 - accuracy: 0.7064
#
# ----- Generating text after Epoch: 30
# ----- diversity: 0.2
# ----- Generating with seed: "Prime"
# Primea  aa a  aa aa aa aa aa a  aa aa aa aa aa a   aa aoa aa aa a a                      ia                 a   aaaaa  aa aa aa aa aa aa aa aa   a   a   aa aa aa aa aa a   a   aa aa aa aa aa  aa aa a   aa aa aa aa aa aa aa aa a   aa aa aa aa aa aa aa aa aaaaaaaaaaaaaaa  a   aa aa aa aa aa  aa aa aa aa aa aa  aa aa aa aa aa aa aa   aa aa aa aa aa aaaaa  aa aaaaaaaaaaaaaaaaaaaaaaaaaa  oa aa aa aa aa aa a
# ----- diversity: 0.5
# ----- Generating with seed: ""The "
# ...
# Epoch 41/50
# 10000/10000 [==============================] - 99s 10ms/step - loss: 0.5228 - categorical_crossentropy: 0.5228 - accuracy: 0.6312
#
# ----- Generating text after Epoch: 40
# ----- diversity: 0.2
# ----- Generating with seed: "An ad"
# An ada a   a   a a a u  i  a a a ia a a a a   a  aaaaaaa             "“o ”i               "“"   yy a   aa a   aa  aa a a a  aa         "“'a  “ au "iy y    aa aa aa                            "“"   yyaa                                                  "“"   yy    a   a  aaa   a a                                                 "“"   yy  aaa a a   a   a   a                "“o ”uaa   a  a a a
# ----- diversity: 0.5
# ----- Generating with seed: "The B"
# The Ba aa   o  aaa     "“'a  “a  ' ea  oou  s aaaaiaa a i        "“% "ay yoaa i oaaoaa   oasa aa e  a e or iia,aa a a   h esoa     "“'e"  '“iba oaa   a  aa  ,aas a a o   i a o mae i  a a oaa i a  a,a ai si a aa a aaaa o i m  , i  a  a e  o ya' a, , aaa a aaoaau  m  i   u a  iam  aaa    iaaoaaa aia ao  a i  aau a a          "“voa"   e aaaa aai  a a eoi aaaaa             ea aaaa aaai  aiae ao  iiiaui ae
# ----- diversity: 1.0
# ----- Generating with seed: "Among"
# Amonga ace  wma k-h'ec m u .a ,e se,aou  iii - o i eeiuaaiaa  ei& e oamrafaae  aa .a t a   ah, taoi)wa sa',,a si u a,-a 'o aue sl' iet,au !wi,mi 'aauiaoo aeiaaeioi khroi ei akmmhaah a'mshmai li a  ,   asu aae'  ,aa&    aah ao ia   a a  aasa  iauoa ituaauoaa,-y a ameseah  oa aea 'po  a e'saius-u,saaaeia'r'anei e,a  aaaauio'setoa hhaa 'osa ssouia a ,suma u sia"aooo mas - oiu,uaio"  aaeaf ai ifaaa aauaase
# Epoch 42/50
# 10000/10000 [==============================] - 93s 9ms/step - loss: 0.5222 - categorical_crossentropy: 0.5222 - accuracy: 0.5411
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: "At yo"
# At yoa     eaaa a aa aa   aa aa aa  aa aa  aa aa   aa aa   aa aeaa a       ea aa   aaaaaa  aa aa      e aaaaaaaaaaaaaaaa   aa aaaaaa  aa aa   aa aa  aa aa   aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa a         ea aa   aa aa   aa aa   aa aa   aa aaaa  aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa a aa   aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaoaaa  aaaaa
# ----- diversity: 0.5
# ----- Generating with seed: "The A"
# The A  aaa   a ia  a,   ia o am  aa aaeae aaaaaaaoah o a a  ai aem aoaaa   ame aa aaa a      a  aaauoa aa ,aa"a  oyoo    oi am  oa  a ae     e  a , a aa i   ma   o a aa  ao   aa aa aa  aea a ma w  aa aa aa,  io aoaeiaaa maaou aa   a  aa aa i  ah  -aa%$       ea  aa aa  oe   i a'sa  ma a aaao a mai aaaaaaaaa  mmi a aa   um aa  aaaaaaaaaaaoaaa  aaa     aaoo a aao a oa ia i aaa' aaaeaaa    aaa   aaaaaaaa
# ----- diversity: 1.0
# ----- Generating with seed: "In ba"
# In bawe -oaiaa'i qai  aemsa aw.hoas ao oooai aa  aeaaoa ia saiaoaasmaa 'gm “a,"““esuyoma  iu s eip h-m i -ep aew 'm'miaeeeo  aim  u s aaeeef.oiaa, 'aiaame aa  a-sa eahmaaa a u amaama- 'oio yhaalie ao urml,aame, am oy h  ' fo,u )aooam hai,aau e,aoo' aaiauia o -  oaai    '""" z'" .mh m "o!s "e$a"?ae   a,aoadrwhaeaaahao.-u' 'aaaaaragai  f um   ,a“i l hvimjo  )aiaea aua;os'aaaa,  ieum.   demt  'i $a ea m
# Epoch 43/50
# 10000/10000 [==============================] - 96s 10ms/step - loss: 0.5216 - categorical_crossentropy: 0.5216 - accuracy: 0.4208
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: "1975:"
# 1975:aai   aaa   aa a aa aaa   aiaaa aaa  a aa a aa a aa aii aaa  a ai i   “““"““Q i [a“ “  “  “  “  “  “ "““ a  $ a   aa a ia aaa   aaa   aaia  a aa a aa a aa a aa a ia aa aaa   aa a aa aaa  iiaaa aaa   i  a aa aaa  i  a aa a aai aai ai  i  a aaa  a aa a aa a aa a aa aaa iii aaaiaaaiaaa,a  iaaa aaa iaaiaaa aaa   aiaaa aaa   aa a aa a aaia  a aa a iaia aa a aa a aa a aa i iaa  a aa aaa  a aa a ai   iaa
# ----- diversity: 0.5
# ----- Generating with seed: "The t"
# The ti a iaaa aaai iaa iaaiaaaiae iia aie,iaa  aae  aa  a aaia iau aaia i,a ai ao  aiiaa  a aa aaa aaaiiaaaa aiaai aaai iaa, ieiaaiiaia o iia iakiaia aaiaua  aiii uo i   ““Y"““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““““$““$“““““““““““““““““““““““““““““““““““““““““““““““““““““““““““
# ----- diversity: 1.0
# ----- Generating with seed: "This "
# This i,amh   “xaoeea,ueao iaumawa mia'oia,)m,oiemaua aeiaarkaioay, e i;a wiiay aruiaaue aaia  uoa  )y iakmeoak  yii a a   m?,ayuyua  aiu ea iia i iahm  ,a ;   $mhr  oo;i,,a-)osa ia    k ““ k“ aoasf,i,a iiii,o aaao e muiiorae afmiuuearao  ,,o'oe pa l uia''igaa, aoe? uah'iaa aa o es oaoghfiu a "  “,,$$Wd )aiaaaieiu a'eoiiioaeu,,uiiayoii'miu)iir) sem  a 'i'u a ydig,okaaoaii iao iiwuuiif a aa "““"ilQ aiait
# Epoch 44/50
# 10000/10000 [==============================] - 96s 10ms/step - loss: 0.5206 - categorical_crossentropy: 0.5206 - accuracy: 0.4909
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: "Ralph"
# RalphaaF._1Y““Paa    o$  aaa 'D“ '(z$ “Q  “ y “ ( Q'“ “(“X“i“" V$v  a''. ,$a“ “a  a "$a(“ “'ja"“ai,““ (“$a$“no'(aa“aa .a“a   “a"y    “ "““ v““ aae  aa““““'““““"““["“""“ a"““.'[$"(Y$a"[o““““ $“va“. ““"$“[“(“ " “"“"m “'" a 2“a$ “ “""““$a“[/1W" .aa““ aa  “  “ "““ v““a, "a  ““"" "a" aY $a“  $“$““wvs o 1“iaa“ e, $)s"E"a "'  m a “.Q“z) aaisFaa“2“aa 'a  $“(““_"'[ '$$a22 '2a'“a“aa" [“““a"( a“ _$ “  m“$  a[D[“a
# ----- diversity: 0.5
# ----- Generating with seed: "One m"
# One m $Q““K"“ "ul"aawaa““ u2 [““"!j]“ ““"" "s$y   i.““[aa $ o,a“a  oea [““ [  X “" im .s, '$ o[a “s"'"u“a'0v"“Y“ (“"(y“"ii.$“1'm a 'V““ “ eya“a“ve“a a “ “  2asai%8 “ “  w.“a“ a ,“aQ2 !“aa.“ a,““““$“$“[(““““["“""“ am" .'oajaa_la,las1y) "a“ “$i'p““o[ o_a0au“uaa“ ,')_“"(h u a   ,i,,  ,“ ““o u"o  P“wa“ “s" asa 2a" [“““ly" e)if. "'““$v aSa 2a“a“eayi“2, ““  %ea“$“iiq" “  ,[$  aau'“Y g“y-i,a'“ “ ae ,o ]aa$a'a
# ----- diversity: 1.0
# ----- Generating with seed: "On Ju"
# On Ju,e) ,'vYasu.2“"m“a“uiy'S$$l.'$ii““2sao' “os"o$ , '.au w“'e m“s Qls"a“.Q“a,t[a   $Y$o[ “'“"oW$!m t2 $ A“?si “ w “u2“",“““$[$““i$“[““Y“?$“ te  $'[[’““iu"““lX  i“Av -(a$' a’ u9'ar1n'_“0ydao. “hAaf  o.?gve“v'2li,su,“$ 6“'9- (aa'w“1“q'“om,o's,[  'i “goeya "i "““ e- Yao a“i“s aXy))“m'asaw$$Y)g''“vFa“X$aay“u““'a$Q“'a$av& uai““w()[““““$“X(“"““““"““["“s.' e-a 1aii.- so e7 v.““eaAie“'“'“  2u,“a'aY_m“)2' “ii
# Epoch 45/50
# 10000/10000 [==============================] - 97s 10ms/step - loss: 0.5201 - categorical_crossentropy: 0.5201 - accuracy: 0.5563
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "Hey, "
# Hey,   $   a e  a aa    a   aaa                a  i   a  a   a          a   a  a         a      a a     a   a      aa     a a  a     a     i   a      a      aa                           aa   a      a        i a         a  a         a  a    aa   aa         a     a       a    a a    aa  a        a   a     a        a   a  a         aa         a           a      a       a a      a         a              i
# ----- diversity: 0.5
# ----- Generating with seed: ""Lath"
# "Lath i i i  -$aw a ae aia  a  ai aaa   aeo  ae    s aa a-  a         a a  a   a a   aaaa oi    ,eaa  h       i ah   i,   a  aua uai  ,aaa  u a,e  aa a aiiaa oa  i a    a a a   ma       ii  a a  a a o ai   i  i aa  a    a af        i    aaam  aaaa aaa ,a iac'   a     iao im     uaaaa h   aa   mm     aa  aa  i  au  a  uaoaa   i a a s , a a u     a i, o ma imia    a aa       a   aaia i  am' aia a uaa  aa
# ----- diversity: 1.0
# ----- Generating with seed: "North"
# North,a.o w uopo m    u ev akw ua af ea,a oi   ao" oo $ aa,u-a as,sihru ,eaa a ooaaoaa   fm ei  meia'ri  oh-eie,i' wo oeidesa mo yaoaioaio   usu eE, ;said"e ,oa'am'e-sa aama i,e Iaa,"iaofo  a uu, 'oi  i w l   iaea,h- iiuey aac,' u raeaaih )hu a a'm- seoiaa, aa aeoaio,oeaiao paulam ie    hioaa.aabsm;ima a,    “a ,e ah eaiboaayo.h uui oiiu w' aauoa aom,sap,umuaoemaoeyih iae ;wi i owaaaoa,im  ei-a asafaow
# Epoch 46/50
# 10000/10000 [==============================] - 91s 9ms/step - loss: 0.5194 - categorical_crossentropy: 0.5194 - accuracy: 0.4967
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "Her 6"
# Her 6aa a a aaa  a  a a aia a  a  a a  a a iaa  a a iaa aaa aia a  a  a aai  h aaaai aa aaa aaa aaa a aai  haaia a  a aa   a aa   a i aa aaa aa   aaia a aai  h aaaa  a aa   a aiaiea  aia a  a  a  a aaa a aa    a aia a  a a  a aaa  aaa a  a 'a aaa aaa a aa   aiaaa aaa aaa aaa aaa aiaaa aaa aa   a a  a i aaa aaa aaa aa    a a  a  a a  a a  a aaa aa   a aaa aaa aaa a  uaaaa aaa aaa ia aaa aaa aaa  aaa aaa
# ----- diversity: 0.5
# ----- Generating with seed: "Becau"
# Becauih  aa a aaai iim am'  iua aaea   aae ma   mu e   ao iiaa ',h    ($ “$ oa  ai a a, aaao aa  m ai o  aaeia  ro  aeai-a    au a eee ao  aa aio  eu c m    iii  i    a i ii aaiai oa a aa iaiaaa aaa  ama  eaahuo  ia a h aia u aa 'meiaa m aaihaa  aaa ai  o ,aaa -o  mi'ouaa a aii  ei aau    iou aw    $,[“i """""([““"“"“"" ““““"“““““"“““““"“““““"“““““"“““““"“““““"“““““"“““““"“““““"“““““"“““““"“““““"“““““"
# ----- diversity: 1.0
# ----- Generating with seed: "Jamb,"
# Jamb,ua io w aud' secpa  , u“p e!"  '“a"““[""[" ““““"“““““"“““““"“““““a“m$ohcjamavim aau)“cce-eow ahm oo" mmo$ oeQa' i oi   a  aah,avhhoe  - haaofuhm-ou  o))usofim-u avu onohia)m, ee,ea,'  io a c,ei  uio,hskaooue haa eua'''mi"“tif"a )a"a“i """i""a“y $g h es.io)ivtde a'hiiuiiiieaahvui e a  aaeeihh s,m uo aoab.i -u iia muii'aouj'livy  e  aui ii uuuu ulo  aa--a ad m  i  o,'ai,ieaakff -iiaaa m?oaiao  aoai
# Epoch 47/50
# 10000/10000 [==============================] - 89s 9ms/step - loss: 0.5190 - categorical_crossentropy: 0.5190 - accuracy: 0.4418
#
# ----- Generating text after Epoch: 46
# ----- diversity: 0.2
# ----- Generating with seed: "This "
# This aaaaaaaaaaaaaaaaaaaaaaaaaa aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa aaaaaaaaiaaaaaaaaoaaaaaaaaaaa aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa aaaaaaaaaaaaiaaaaaaaaaaaaa aaaaaaaaaaaaaaaaaaiaiaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa aaaaaaaaa aaaaaaaaaaa aaaaaaaaaaaaaaaaaaaiaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa aaaaaaaaaaaaaaaaaaaa
# ----- diversity: 0.5
# ----- Generating with seed: ""Eye "
# "Eye .aueaae a'aamuaauaaa aiaiaiaaiiaa maaiamuoamaaaaaaai,a iaaaa aaaaaa iah   ae aa iiamaaoaaaa aaaaaaiaai i aaia a i aaaaia a a aeaiaaea  aaua mmaaaaaaaiaaaaaaoaa  aaaaaaiua a aaa aaa w a aoasaamaa a  uaahaaaaaa iaaeaam aaaao  aa mo  ,aaaa aaaaaaaaa aaaiiaaaaa uaaa  iaaeaaoa uaaeaaao aimao oaaa saiaaiaaaia a,aa   aeiaamhaaaa aaaaaaiaaaaoai aaa   eaaaa aauaaaa aaaoei iaa-a ae  aii aayaamau aeaui eea
# ----- diversity: 1.0
# ----- Generating with seed: "The M"
# The M ,fpeeaai ua uioi ',u'ah) e'aavasay aa a- imaifaaaaa,i,aaaaieai'm   hu speio ohaa.o a,ayaa   of,a lla ae ,i a v aono agua,aaaiiit'aae v yfaaeoa"  ia"$jimaaaasa,a ei',osa;eua auhoa abio"mu a oaaa) u h saamotfua moaa)o)a,o, ey iuiaam   ,iioa.u m auaai aaa o   iiieii-,ialwi at :'“$““Y“ aaaoi o'gmo'iooeascaa'uaai afpkmqt amu q ea a-mi'goehaoasi'a miouooa i!a'ahamhu;aaiawmamigm'aacau feo a uiuawo'aa m'
# Epoch 48/50
# 10000/10000 [==============================] - 88s 9ms/step - loss: 0.5186 - categorical_crossentropy: 0.5186 - accuracy: 0.4232
#
# ----- Generating text after Epoch: 47
# ----- diversity: 0.2
# ----- Generating with seed: "You'l"
# You'l    a  a  a  a  a  aa aaaa  aa aa  aaaa  aaa   a  aaa aaaaa  aaaaaa  aa a a i  a  a  aaiaa aa aaa  a  aaa a  aa                 ya  aaaaa  aaaa aiaa  a   aa a  aa aaaaaa  a  aa   a  a   aa aaaa aaaaa aa    a a   a a aa                                                    ya               """! """a   a a  aa a   a aa aa  a a  aa  a   a a   aa aaaaaaa  a  aaaaa  a  aaa aa    aa   aa a  ea a aaaaaa  aa
# ----- diversity: 0.5
# ----- Generating with seed: "This "
# This iaaao  amaaa  a ia  a aai a           """, “ a)( a  ei     y a  aaa iaa oaaaa  aa o a 'aa i  a  aiia  ia  aaaa  o aa, a  a-a  a ,eaaa  aaaaa aa   oa aaae a a  ae  aa ai  a  a  a a aia      yaaaaa aa iii ihaaa aeai   a  a  a  u o aaa   s a aa  aaa a  aaa  aaa   a i ;saaa aa aa iiaoiaama      ""!ah   iaa a aia a i a '   a ai a-aa aaa  a i  a i ea  a aa,aa  aa aaaoa    i   e    aa aa aei a ao  aa  aa
# ----- diversity: 1.0
# ----- Generating with seed: "Broug"
# Brougk a 'a asm   aaa,e) aar  asa ekiieiua, ioia o'uoa,la ie'aa',  e  -ayfaia'iaa aa o,aas, i mee eam'ha,a  ahE., i ai  iita-i aa  ao  iraaeeaies-aeim : a  su  e,a"hgfr$aafi ,owoiaiaoma''s ie aaahoaa 'aa ee au'aou i a u ahii)  m ha hmi;s- s ia' ', j' ie viivm   sy,, a amf )a aia aai ''ae'i'aao,ew o ' aa  oa c s'ha aiwis;a aeu aam  ds- amaeamwami,o'' iiu  --ha   uoiaaa  )ate ma aea aitwo i eiaosaaa ai a
# Epoch 49/50
# 10000/10000 [==============================] - 94s 9ms/step - loss: 0.5179 - categorical_crossentropy: 0.5179 - accuracy: 0.4456
#
# ----- Generating text after Epoch: 48
# ----- diversity: 0.2
# ----- Generating with seed: "If Ri"
# If Ri  aaa   a     aa    aa aaaaaaa    a  aa  a  aiaia aaa  aa a   aaa ia   a aaaaa aaaaa aa aaaaa a aa iaaaaaa i a  a aaa aaa aaa  a a   a  iia aai a aaa  a a    iaa a aa a aa aa  a a   a a aaaaaaa aa  aa aaa  a   a aaaaaaaa  a   a a    a a aaiiaaaa aa a a   ai aaaa  a   a a ai    a  a aaiaa     a  a a aa    aaaa      aaa aa   a a a   a aa aaa  a  aa  a  aaa iaaa aa aaa  ia  aa aaaa   a   aaia  aa aaa
# ----- diversity: 0.5
# ----- Generating with seed: "Sick "
# Sick  aaiaa    ii aa ei  i   aa aa   a  aa  a  oaa ia  ia a  io ae  aiia io     a  u iaaa a aa uo  aoaoa i  aaiai ao  ia,eaaa,    aiuaaaoi  a a  a  a aaiaaa aaa aaiao  e ,aaaao  o a   u iiua i iaa   asaa i   a ia  a a   aaeiai,  iaaaa a a amei  i iia aaia aia  aai  iiao a io oa a a  aaua ia   aa , au aaiaaiwaaa ia i   aaaaa a a  a       i'aaaaa uoaaaa  aa   iuiaaaa a aaaa aaaaioaa'isae a iaao aiauea,ai
# ----- diversity: 1.0
# ----- Generating with seed: "In th"
# In thi oo - a,a fq aaeh,hioe: ihiaih i  -aa aa   uopo'oo a' aeoio i.m, eoeifaaeoaa '!ea ' ah woai,a  o,   aia oeioaowwa  saiw') -  ea  aeia ep '!"af" iaayami  ui   aaa,m'maa,o ahiifhaao a:a  aaso-oi i,ai hH    afi ,aiuau aeio eaiaoo 'im aai. migi  y oai o oa''hakaia e , awa waeao hwi aiaj iyi wa-iaac wuli'f sau  'ho raaceiohai ,'ai  ak  ekmaaef haaf  a iiioie ,'aaBaa wois,wai i faoieawa,a u  i ,oii oie
# Epoch 50/50
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.5173 - categorical_crossentropy: 0.5173 - accuracy: 0.3977
#
# ----- Generating text after Epoch: 49
# ----- diversity: 0.2
# ----- Generating with seed: "You t"
# You taa'''''$“o  a' '  “y(a“  'a  '  ' a '' '''“'  a'a'a  '  ' '  “y(a“ a  a '' ''a(a ''a'$  '“a  a '' ''a(a  '"' $a“  'a  a' '  “y(a“ a   ' a ', a a '    u   ' a '' '' a   ' a '' ' u,'aaaaaaoa ' '  “y(iaa 'a  a' '  “y(a“  'a  a' '  “y(a“ a   ' a '' ' a ''    a '' ''a(au a  '  ' a '' ''a(au a  '  ' a '' ''a(a ''a'$'  'a'aa '     a ''   '“a  a '    a ''   '“a  a '' ''a(a ''io a'  '  ' a '' ,   'a''    u
# ----- diversity: 0.5
# ----- Generating with seed: "In th"
# In th'a '''u a 'eai'' ' a ', ,aa i  o'ia 'a' “.m"  'i$ i ,,i 'ai f ' ' i' a    ,   'a'' ''a$'uu s   a '' ' a '' ''  'a'aa 'a  a' ''e“a, oa ''   i'' i ' a ''. aum   'o$'aa' , ''aa%   ia     a ' a '    u 5a.aa  ,' '"a“ "( “$a y a ''   '“  “% !'' , , ', u'' '  “y(a“  'u    '(' '““ a a' '  “y(a“  'a'aai'''''(( y - ,' '"a“ "(,( ' , a,  i v'ua  'aa aa   ,  ' a,  ea '  u  ' ' a '' ''a( a''   ua'  ', a a  ' u'
# ----- diversity: 1.0
# ----- Generating with seed: "Chlor"
# Chlor , a t "oo!a au af,e'i  ' ' f. 'a 'iaa')'e7" . '  ' 'mu“a,'s,,au n  a4uua) ? 7aeuef-e,Ai 'u i,,,iu ,a ,  's',“,,"en ' .,:ia  ,,'as 'u:$eu w,ui' n ,au ui,e   ) '.',)'t: ea f  ,aao a'ip'aas vhu) )ii aasoa oo', ,,ee' auau:eaaoyaieus ,6, 'we?a' oa:'ki) o','e,f,-u'a'i o' a w''''oa'a,e, ' uas'ie,C.'t't'''a   . haa  'y',, o uua f, a  -' '“""y“u & .''('ieu5Rau 'o'u,,ua ''a'“ha i  u,,ie   'o$,i i,u'  'u,-7
