# %% [markdown]
# ## ANNDL Final Project: Jeopardy! Question Generation

# %%
# This notebook will train an LSTM on a set of Jeopardy! questions with the goal of producing novel questions.

# %%
import csv
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
import random
import sys
from keras.callbacks import LambdaCallback

# %%
# Load data.
data = []
with open("/Users/fiordali/Downloads/JEOPARDY_CSV.csv") as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)                                # Skip header line.
    for row in reader:
        if "<" not in row[5]:                   # Exclude videos/photos, questions with formatting.
            data.append(row[5])                 # Keep only question text.

# %%
# Break into train data. Test data????
train_questions = data[:10000]
text = "".join(row for row in data[:1000])

# %%
print(len(text) / len(data))
print(len(text))
# Out:
# 0.37014297076567926
# 76322

# %%
# Map characters to indices, vice versa.
chars = sorted(list(set("".join(row for row in data))))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
# Find length of longest training question by character.
maxlen = 0
counter = 0

for question in train_questions:
    for letter in question:
        counter += 1
    if counter > maxlen:
        maxlen = counter
    counter = 0

# %%
seqlen = 100
step = seqlen
question_snips = []
for i in range(0, len(text) - seqlen - 1, step):
    question_snips.append(text[i: i + seqlen + 1])

# %%
print(len(question_snips))
# Out:
# 763

# %%
# Turn every question into vector indicating which letter is present (in x) or next (in y) at that point in the sequence.
# seqlen = maxlen                                # Length in chars of longest question
# x = np.zeros((len(train_questions), seqlen, len(chars)), dtype=np.bool) 
# y = np.zeros((len(train_questions), seqlen, len(chars)), dtype=np.bool) 
x = np.zeros((len(question_snips), seqlen, len(chars)), dtype=np.bool) 
y = np.zeros((len(question_snips), seqlen, len(chars)), dtype=np.bool) 
# for i, question in enumerate(train_questions):
for i, question in enumerate(question_snips):
    for t, (char_in, char_out) in enumerate(zip(question[:-1], question[1:])):
        x[i, t, char_indices[char_in]] = 1      # Log which character is present at current spot in the sequence.
        y[i, t, char_indices[char_out]] = 1     # Log what the next character is in the sequence.

# %%
# Model structures.
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars)), return_sequences=True))
model.add(Dense(len(chars), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(learning_rate=0.01),
    metrics=['categorical_crossentropy', 'accuracy']
)

def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)  # softmax
    preds = preds / np.sum(preds)                #
    probas = np.random.multinomial(1, preds, 1)  # sample index
    return np.argmax(probas)                     #

def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text."""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    #start_index = random.randint(0, len(train_questions) - seqlen - 1)
    start_index = random.randint(0, len(question_snips) - seqlen - 1)
    
    #
    for diversity in [0.2, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        # Seed for generated question is the start of a random question from training set
        # question = train_questions[random.randint(0, len(train_questions))][:5]
        question = text[start_index: start_index + seqlen]
        generated += question
        print('----- Generating with seed: "' + question + '"')
        sys.stdout.write(generated)

        for i in range(200):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(question):
                x_pred[0, t, char_indices[char]] = 1.
            
            # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
            preds = model.predict(x_pred, verbose=0)
            next_index = sample(preds[0, -1], diversity)
            next_char = indices_char[next_index]

            question = question[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print("\n\n")

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# Train network, print generated text at end of each epoch.
model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback])
# Out:
# Epoch 1/50
# 763/763 [==============================] - 3s 4ms/step - loss: 3.9048 - categorical_crossentropy: 3.9048 - accuracy: 0.1086
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ill in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter "
# ill in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter    t                                     e                    o  e                                                                                                                                  e
# ----- diversity: 0.5
# ----- Generating with seed: "ill in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter "
# ill in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter o    r  e e h a  mee  e  ni  e  n     s    oe e   n   s ee   p s  o  ef  o   e sei  i  e  n  le  y        e e  lt e  e   it es e     te   n er  rer  n  i o   r    h r   ie r r      sr tsteitsor el  ln
# ----- diversity: 1.0
# ----- Generating with seed: "ill in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter "
# ill in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter n p ahsnf  eksnn adltdwo sledm n mmk,  a  tem dtuoof  s t c Otneseeo r ra iS o  r  eWra iouou nssaeoanhees  ia lroefpcme  Tacu  sp n   Cn a…ts,ifeo     ry t m p  ceu  sa  i pia"etesInt s  slasdv se  b
# Epoch 2/50
# 763/763 [==============================] - 4s 5ms/step - loss: 3.2322 - categorical_crossentropy: 3.2322 - accuracy: 0.1647
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "erage of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company s"
# erage of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company s                  e   n             t        ie      e s         i                  e e          e         t                                              e      a  e                         s     e
# ----- diversity: 0.5
# ----- Generating with seed: "erage of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company s"
# erage of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company snl a hioe d t    t   toe sit     h   wat htoe eas  a  t  haae  o t  i  e t     iuoo n a oe te er  abe  s el  stii  a  t eees  l  e   ie s ehi o    o u r   ttoo a    h sii s de    ne   S d  e   ufoo so
# ----- diversity: 1.0
# ----- Generating with seed: "erage of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company s"
# erage of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company s t'etdcer i  f deto hbwic rr t istfdisau sitlht  d ntei do siahm itsta ee oatdcn rrnntmnabfpwtÉit riaiIf9ot iI5oeh  trlntI teo  yt r S liiot o h  o,aese r onP@rr lbteg onh iaa hisIgirrpoa e rgbhUtsle
# Epoch 3/50
# 763/763 [==============================] - 3s 4ms/step - loss: 3.1963 - categorical_crossentropy: 3.1963 - accuracy: 0.1726
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "nstitution of Mass., second President of the United StatesIn the title of an Aesop fable, this insec"
# nstitution of Mass., second President of the United StatesIn the title of an Aesop fable, this insec        t                        e  t  e                 a                        a                                  n                                      e  t  r                e s
# ----- diversity: 0.5
# ----- Generating with seed: "nstitution of Mass., second President of the United StatesIn the title of an Aesop fable, this insec"
# nstitution of Mass., second President of the United StatesIn the title of an Aesop fable, this insece aeni  l n  s y     u acern m i g n    an  ae r   ue t  s enr  nw  tr l sri tris    t e   i  g y    r f  n ne   r  dn t ac en  al     snses  lr y     p  ne l p wn    i  s  p d m onp  i   t  te  a   p
# ----- diversity: 1.0
# ----- Generating with seed: "nstitution of Mass., second President of the United StatesIn the title of an Aesop fable, this insec"
# nstitution of Mass., second President of the United StatesIn the title of an Aesop fable, this insecstaut aaVTdi  r9wd.e wr ansI tmsnd agenrhr,sll,ests T  byi risusp ra i'p)tnep dt flArifTssnn uep  t   Thionssnhttrnnso wn  i l MRepmne 8d rc  flyiDbroua p sidin  ma o gscurnis olrun n pgvrs,tlenea1iet
# Epoch 4/50
# 763/763 [==============================] - 3s 4ms/step - loss: 3.1206 - categorical_crossentropy: 3.1206 - accuracy: 0.1806
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared"
# on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared s  s s  s n ts s t n s th      t t s   s  s s s s ts s s s ss n s s s on  s s s n s n s n s s s s s  s s ton s  s s s s t  t s s s   s     s s s n s s s ths s s r  s s s n s s  t  s   l  s s s s s n
# ----- diversity: 0.5
# ----- Generating with seed: "on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared"
# on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared ts a n nt n es c  ts ttnn  t  s m t nn s s nn s n  as  nis n th mtson s s n nss s ens s the  sas ve  es n s  sos le e e c sn s ns n t f sorst eps s n tnn std otcts nas  n is t  s os sntotsn s sat nss
# ----- diversity: 1.0
# ----- Generating with seed: "on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared"
# on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect sharedTºn  sethaeespossp ae mm"  Sw ,me besile  st hss lwMeeunyt otlacwnnlnss 9se ltEaab"ton s narf1n s. ngss'r rtwodon" t dstonr5the gofsnatodssnttel mLb aeo Iwp ltoisitendesnnsinwsd9hit2%mh,oy2d  usnd sts
# Epoch 5/50
# 763/763 [==============================] - 3s 4ms/step - loss: 3.0829 - categorical_crossentropy: 3.0829 - accuracy: 0.2046
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "t for espousing this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 ML"
# t for espousing this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 ML th r the  s s th  o  te  t n te  on this th    a t  or ot the  in thin  the th r th  an  t th   te  on  or th  o the  on th  th  in  on the o  a  a  n s  o  o  a  an the on th the this a e to  t s th
# ----- diversity: 0.5
# ----- Generating with seed: "t for espousing this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 ML"
# t for espousing this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLae e oiwerit  os rtris thin oat to ia th n thereoa  th s  hh  this itie wha on  at tt the eote   hh ten an hee taf ris no e t e  at es ti cil nsd re  ches ton d  t"d ao oill  an rser ta  ot  ian rea t
# ----- diversity: 1.0
# ----- Generating with seed: "t for espousing this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 ML"
# t for espousing this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLrietmerotifcdtaidSn my sdns, Id  ts wnoa cyg  ufrw, ) loirtPhccay o0e tor s Thei satydfr-ryfpiscls wayd Hiu& 8ayozucogs 5 riur5oto. rektit Persve "olsrire  lwaCmuC ptea odyny iselmeto in k  Sntes C ni
# Epoch 6/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.9629 - categorical_crossentropy: 2.9629 - accuracy: 0.2258
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: ""The Art Linkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., fra"
# "The Art Linkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., fran the the  he the the the the the the th s ore an ton the the the the  on the the the the the the an be the the the the the  or s s s an the the the the the the the the the the the the e the the ae th
# ----- diversity: 0.5
# ----- Generating with seed: ""The Art Linkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., fra"
# "The Art Linkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., frat on n e n thes on re ae Li  is ne " ae chan "as s po che  he the s the the thera rert oa h s s e  or sa d ie ee ein the therr oo ecor be th rhar  nsrate thnlon  on as s red the ea aan thr this thus o
# ----- diversity: 1.0
# ----- Generating with seed: ""The Art Linkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., fra"
# "The Art Linkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., fraFht WeudTin etfn aaderle hhm annesauime teet n eeLanch  ti wos s peebfofes ch nes acot rilaS  oeten e  aotine olits Lo  teeath ianR .ontcy parou1an liae hkdista Ai th wo  conbmodn Coum mentelarbiel1 G
# Epoch 7/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.8240 - categorical_crossentropy: 2.8240 - accuracy: 0.2673
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company"
# average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company the then the the thes the the thes the thes the thes the the the thes the the thes thes the thes thes the the the thed thes the thes the the the thes thes thes the the the thes the thes thes the the
# ----- diversity: 0.5
# ----- Generating with seed: "average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company"
# average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company att s in the nrid the taelir nd t te thed thin thes thes ar th s te the thed disn the  frthententhes ftre thes  the lt the s the thed as thek f mis w thin thes thos thed on thes f teres, the ton thes
# ----- diversity: 1.0
# ----- Generating with seed: "average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company"
# average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company: wa '07d t nor s man7kTheva!, CaiauThe "ts btdbCranmhtn Cobediunngcacg tnd Lhs se ske nnut pus "nste,l0euflsstersñ fctn Stj l de dertn ôolsior'vormrd te n nhm Uit bhertin thednT-rgtton2cad sdvthss oe
# Epoch 8/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.7263 - categorical_crossentropy: 2.7263 - accuracy: 0.2772
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "esThe city of Yuma in this state has a record average of 4,055 hours of sunshine each yearIn 1963, l"
# esThe city of Yuma in this state has a record average of 4,055 hours of sunshine each yearIn 1963, lin  on the  he the  an  t    e the  on  on  th  the the  on  o   a   o  the the  an  an  t   a  an  an  th  t   a  a   a   o   in  f  t   t   t           t            n  on  he the  in  on  on  on  a
# ----- diversity: 0.5
# ----- Generating with seed: "esThe city of Yuma in this state has a record average of 4,055 hours of sunshine each yearIn 1963, l"
# esThe city of Yuma in this state has a record average of 4,055 hours of sunshine each yearIn 1963, lo n " th the d in  an  ar tes ce w  te the t t  s che a t a   be so  e  he 1In  he  a  1  he  is  on in  in  th  s t e te por  ia  til  o  er s bis  a  Fon 19 In  at  t  is  on th  te   a  al the the
# ----- diversity: 1.0
# ----- Generating with seed: "esThe city of Yuma in this state has a record average of 4,055 hours of sunshine each yearIn 1963, l"
# esThe city of Yuma in this state has a record average of 4,055 hours of sunshine each yearIn 1963, llr  Me er f haot  us tnms re ist alt Hos ti  i  te I6 190d the mo kt e ". Wh  "D Ce g e  ot  oaf ler ofe te " shie w iis Tis  De a t-) te cou fite "M"Thi s th d  he the, voa hy'me,, 1li w cap OA  He w
# Epoch 9/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.7080 - categorical_crossentropy: 2.7080 - accuracy: 0.2717
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "he title of an Aesop fable, this insect shared billing with a grasshopperBuilt in 312 B.C. to link R"
# he title of an Aesop fable, this insect shared billing with a grasshopperBuilt in 312 B.C. to link Rore the this an the the the this the the the the the the the the the this an the the the the the the the this this are the ther ar the the the the the this this the the this ar the the the the the the
# ----- diversity: 0.5
# ----- Generating with seed: "he title of an Aesop fable, this insect shared billing with a grasshopperBuilt in 312 B.C. to link R"
# he title of an Aesop fable, this insect shared billing with a grasshopperBuilt in 312 B.C. to link Rope a tine toun in is of core ooureantia ban  or tare thas A thu the the warion this antpor thas the the wanis of on the The the thes fort ame this aan aeica this an s of cary of the ar ond of se the
# ----- diversity: 1.0
# ----- Generating with seed: "he title of an Aesop fable, this insect shared billing with a grasshopperBuilt in 312 B.C. to link R"
# he title of an Aesop fable, this insect shared billing with a grasshopperBuilt in 312 B.C. to link Roalmouvo sis boliIr anesgarlesd)!areraakluales givesWorldAteis beeraeiloan ther soufPars bheent pies ari San yafrelcoytamerisTir sas toule Faysewangorhe oftheedilithioiodeatirrVAulle"Ihidi' iate pomi
# Epoch 10/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.6154 - categorical_crossentropy: 2.6154 - accuracy: 0.2900
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "g this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with"
# g this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons withe for this this thing for wars fon thes for the for the for thes for the fart fof this forn thang this thes for this the this thes for the for the for this for this fors for the for the thes for ther
# ----- diversity: 0.5
# ----- Generating with seed: "g this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with"
# g this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons witherf an Partangang 19884 of pogt for mons fond thes fore favin wangr cor portiant"B forteffrof the barngs focn tor thed forlad fopnind fart for thas thing and 1964 this fornthing fof fand the 1920 196
# ----- diversity: 1.0
# ----- Generating with seed: "g this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with"
# g this man's theoryNo. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons withesquctian thesAntbrapar! par cs moxt ?s Thitd Sff,thinfprrss that sominl tou k of In toa"Ahangy"samnondma"Afrcths CaamiupfCav.Snthsa wrbLr "0auTat fhansCras torncfring thiseHmavn prttamsa poathitfowds
# Epoch 11/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.5818 - categorical_crossentropy: 2.5818 - accuracy: 0.2956
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "er of the Constitution of Mass., second President of the United StatesIn the title of an Aesop fable"
# er of the Constitution of Mass., second President of the United StatesIn the title of an Aesop fable the the the this thes the the the the the the the the "In this this thes this  and the the the the the this tong the the the the this the the the this the the the this the the the the the the thes th
# ----- diversity: 0.5
# ----- Generating with seed: "er of the Constitution of Mass., second President of the United StatesIn the title of an Aesop fable"
# er of the Constitution of Mass., second President of the United StatesIn the title of an Aesop fable ad 1950 s ane tore A the waf the Bean thas "San "is on this s te this The  onte ton  ile fome s of the tope of tong the te the this 1977 194 in 1999 s blate tord tor tan te s of teat " on se end ton
# ----- diversity: 1.0
# ----- Generating with seed: "er of the Constitution of Mass., second President of the United StatesIn the title of an Aesop fable"
# er of the Constitution of Mass., second President of the United StatesIn the title of an Aesop fabled Ro thyu(A Eand O cI00 Thd tha , fi. ke"y yt sd wlove late ingbas w an aine t, an pof "1dt'sa thestot Mss ove 200!"Incta LastOmas if Vis dow Ran on tf theom Anunycty U. nan a9 Aney"2 te Bktcokl le wt
# Epoch 12/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.5213 - categorical_crossentropy: 2.5213 - accuracy: 0.3075
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company served "
# of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company served this the the the the the this the the the the the the the the the the the this the the this the the the the the the the the the the this this an the the this an the the the the the the the the this th
# ----- diversity: 0.5
# ----- Generating with seed: "of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company served "
# of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company served an the "In for the the s in the be the mave ca the this on the the calin s the barog the  on 1997 the coult tore the A on the "this ar hit ntas this tho this the this alame the s as wais aras in this
# ----- diversity: 1.0
# ----- Generating with seed: "of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company served "
# of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company served Doun are4 is Foushy of this to Thh sed na's gak hins Chiof Asthis this teuspes" pen, fnoproun walaWiop bolinid tlats)e2981251It thin cho , "Sthe yer oflo thede wor'n Benen folger 1900, inatle Wait'in
# Epoch 13/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.4922 - categorical_crossentropy: 2.4922 - accuracy: 0.3088
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "easons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 ho"
# easons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hor the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the de
# ----- diversity: 0.5
# ----- Generating with seed: "easons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 ho"
# easons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hor the the the sore the oud are this the the this the the the the the this aris this the the corn on in toum tre melle ter the wert cor the the the the thin serad tit t r wre te the tha this the the wa
# ----- diversity: 1.0
# ----- Generating with seed: "easons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 ho"
# easons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hou painin stirn nee shicglld urtogwaveamior loH sty'n prat & "Haunhar thure arn frertectspleneurfhouNt6 hion Brprytaraltrinis ars & "culbendler chs pop ir , Inedrrrhe pirhe ded thinn 2, thlred tvir Eu:
# Epoch 14/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.4360 - categorical_crossentropy: 2.4360 - accuracy: 0.3208
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma i"
# tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in this the ware this this this this this this "This the this this this s this "This s alle this this this the s call this this this this this this this the s the s this s the the s an this sithe s the
# ----- diversity: 0.5
# ----- Generating with seed: "tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma i"
# tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in 1942 Polly tatin mitt this "The Mange 1997 Wing s ed the  are this pleded serte forr callon se wast in thes came was com th s of this dome a the l of the the d the 1997 1945 is this urcall beatt wis
# ----- diversity: 1.0
# ----- Generating with seed: "tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma i"
# tball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in arg this omsyinlOscabeX tha amtist canthas , isa  acn Peats ant anay p th's sDtoe funhcist antoprowing usgrt unger-vird wang LukntThe A in this ffltre In SMonhe swins Pealf on cerin ald Mct mameI te
# Epoch 15/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.4268 - categorical_crossentropy: 2.4268 - accuracy: 0.3245
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "th the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of su"
# th the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sur this the shis the this the the bor the prom the this the shis the this the for the stor the stat this this sthis shis this shas this this the she this the was this the this in the the the this stat
# ----- diversity: 0.5
# ----- Generating with seed: "th the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of su"
# th the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of surs a the this  or this the "In 1899 this she in this com this she the Mart in er thes the the Shis shas in the Pron a shis cap sirs the beche Crre this thes co man s stis "This firs an the this is thi
# ----- diversity: 1.0
# ----- Generating with seed: "th the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of su"
# th the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sun 1663 mathe Grotaf the  on "s in Crissbors" sjacklr mor ohisndb recy the serociquede thes this gham stemler" he 18989Fhttrer Bris is the Eat DeIs Gliin Ed of this terst of the of the matin mounar  of
# Epoch 16/50
# 763/763 [==============================] - 3s 3ms/step - loss: 2.3704 - categorical_crossentropy: 2.3704 - accuracy: 0.3386
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "n 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmin"
# n 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birming the wate for the seanted the wast an andeng the was the parle stang of the wast the was an andere the the wast an the planged the sant of the fors an the for the bellest of the the was the anded the
# ----- diversity: 0.5
# ----- Generating with seed: "n 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmin"
# n 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birming for thes ponging the fomes of the pelass of the forsent ffre the panglises for in the procke fromed an en the wast in the this bale this this counsts in this stafting forston speatthe peathes as com
# ----- diversity: 1.0
# ----- Generating with seed: "n 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmin"
# n 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmingtars yelot", theWhen thes crypoted lockonch amestia pilcuse hisevesponger 1974 polpacn thes Vind StalsingsedkAnthe uuteto he uliwicape this " anetinslloncThle 1000B. 1061& the bpes this "DoethonMavin
# Epoch 17/50
# 763/763 [==============================] - 3s 3ms/step - loss: 2.3528 - categorical_crossentropy: 2.3528 - accuracy: 0.3352
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "s state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linklette"
# s state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter war a promed a pround of the seanter of this s as the seand in the seander in 1996 he was this siantris serate a seand of the seander a beald of the counder war the serand in 1969 his the sering thi
# ----- diversity: 0.5
# ----- Generating with seed: "s state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linklette"
# s state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletteromenghis ander withe is are or the wirg of 1995 her The Bellacher sor this in 1971 & mate se the U.S. wory in this seatided of this laris sertire seaning a coully of shalisor the Thes a larkis in a l
# ----- diversity: 1.0
# ----- Generating with seed: "s state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linklette"
# s state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linklettendares ergigttts.He aping sickake formfiodled 40, lis moun"Jancthes Virye hayadist foridark col clodecisjor a lacey in this Deindarm acauons belininged inn"This strlondisple frow Biangan & U.curodBenv
# Epoch 18/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.3355 - categorical_crossentropy: 2.3355 - accuracy: 0.3411
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: " this state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkl"
#  this state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkly the this the the the the the the the the the this the the the the the the the the this the the the this the the the this the the the the the the the came the wate the the the the the the this the th
# ----- diversity: 0.5
# ----- Generating with seed: " this state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkl"
#  this state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkly the the thin callice this souce thit this the withe the this seatt a the it's in the lath the er of the the Fastina the thith a wead is the wing Mation thite the sied thit this chate the firy the th
# ----- diversity: 1.0
# ----- Generating with seed: " this state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkl"
#  this state has a record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkly "Ed dic. L igias grayowed: fsamigess offpeeet eathies inctibled"Eg 2, 19sI polarura'3 lary thuanamo fofte & king a Nict the  ostifered of thit, bochir & 1988Tivh whisery tSe & thatThe thor ditarow:
# Epoch 19/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.3040 - categorical_crossentropy: 2.3040 - accuracy: 0.3524
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves"
# 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves of the stare of the 1944 the "The Amer a seat of the was the Cor the coun the prome has "Sout of the Sume the prome the was in 1972 he the "This the por the U.S. Sou the was the mand of the Call of t
# ----- diversity: 0.5
# ----- Generating with seed: "1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves"
# 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves the wist row this bet a comptris a mome this sas a derien "The singe tt the 2000 is a shane a beare of the Bors a bute a porly of the U.S. was a the for "Eve the 1999 this seas a a this the beg's pat
# ----- diversity: 1.0
# ----- Generating with seed: "1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves"
# 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesIt the gollanb oo out t'ou's 1962 Mav hancthy a wariscaA & BousThis of 2 Lrove for a thiis Moses, In ios 1391 mared this che this is comitito fromed cuscabincon Wiss, mant rf witeTaziBet was a teind "
# Epoch 20/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.2686 - categorical_crossentropy: 2.2686 - accuracy: 0.3592
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "se todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-"
# se todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-with in 1962 this pring this stant of this stan in a perical star the for this stare a pering in 1992 this stare of this poris of this can a comenting this ser the was mant of the was sen this star a
# ----- diversity: 0.5
# ----- Generating with seed: "se todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-"
# se todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-pont a frop and red a comeaning a  an a besting stan can and on this contillt in the signaly an this fir vere in Manter of on this der an, 1954 he rilland of the mever in 1950 ham tove for "This maner
# ----- diversity: 1.0
# ----- Generating with seed: "se todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-"
# se todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-uniliughey y's 1n422-youstane of in was gity "of fise F fre Br.Oitt io Ho bic U.Mive Inithad sseng of spaes and qust is god of this geben win bok Yon toverict ki in adlever prectanddet, of this rivo l
# Epoch 21/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.2744 - categorical_crossentropy: 2.2744 - accuracy: 0.3574
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "age of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company ser"
# age of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company serist of this for this stith of the bare of this seater for the seaner was a plane of the was a berist of this bering of this seanter of this seanter of this sound an a plant of this comering the ware a
# ----- diversity: 0.5
# ----- Generating with seed: "age of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company ser"
# age of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company seresher bortar wordich meathit inamed is the Mantial Frontion monkere sounthe wise was a plore sean your was Jord of the seaning you the seatere an was on a privil & wased was apruce of the sored the Cr
# ----- diversity: 1.0
# ----- Generating with seed: "age of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company ser"
# age of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this company sery of a wondMa, "sairserte whishes, one nome frous to beSkre Bomecick-brorzery anvor eadnion A11 22-1591,'670:'88 wole s of 2001, this 19nves whhe Core mouchowe Marion ow Wilsoumistrighe, & wheesy in w
# Epoch 22/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.2347 - categorical_crossentropy: 2.2347 - accuracy: 0.3674
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 ste"
# grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 stede the sond the was the anded the was a stanted the penting the was an the seath of the was a plant of the Conded the Seathed the wast the was an the Canded the was the seating the the same state the
# ----- diversity: 0.5
# ----- Generating with seed: "grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 ste"
# grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 stentand ancht canded an was the 1992 an on the Ling sed to the Candang compangationt of this songen of this tome an 1913 pattes an 1998 this coust catsed of the panted thes amed the Binking formed the S
# ----- diversity: 1.0
# ----- Generating with seed: "grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 ste"
# grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 stented this companvinses In hese hiversayale as inmededOncan was  x tolewP$this coutt Hamitamid this hit cest. onElasts, Conate, concon forke forted intien"Thise wees mang of Stomboundel of the 17, Fast
# Epoch 23/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.2093 - categorical_crossentropy: 2.2093 - accuracy: 0.3719
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "illing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use toda"
# illing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todan this stand this this first of the senter senter in this first in this senting this this seat colling the sent in this proter seate this sean in this sting this this canter colling this collice seat
# ----- diversity: 0.5
# ----- Generating with seed: "illing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use toda"
# illing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todating this sarmed for this en the Belanicg the warde stari an solled plalil Stalle with senct the bentis "Repits ponting site the oute this plower desion a playe this first fround of "In was this dimes
# ----- diversity: 1.0
# ----- Generating with seed: "illing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use toda"
# illing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todalis Aresterir teaser juwid sunderre wlofion's Creilised ses ruen is Samon thener exsofkPAlin Frevicod to asegirs lish"tu scande formallis tuins, foombe, chaner Ifludlel & "In will hellead crusted core
# Epoch 24/50
# 763/763 [==============================] - 3s 3ms/step - loss: 2.1990 - categorical_crossentropy: 2.1990 - accuracy: 0.3761
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "igner of the Dec. of Indep., framer of the Constitution of Mass., second President of the United Sta"
# igner of the Dec. of Indep., framer of the Constitution of Mass., second President of the United Stat s man a the lard of the was "The pars and a sound a dear of this compar "In 1995 he land of this star sor "The wis "In 1998 this sear a compar of this spar sall for this stare in this star sing the
# ----- diversity: 0.5
# ----- Generating with seed: "igner of the Dec. of Indep., framer of the Constitution of Mass., second President of the United Sta"
# igner of the Dec. of Indep., framer of the Constitution of Mass., second President of the United Stard & Som the Pand "The wat And a commen wor "This same is stan sor for "This prang a the 1994 to was the Comedund of the U.S. in this comper a cand was a rever a sanger the seat to his for "sourd on t
# ----- diversity: 1.0
# ----- Generating with seed: "igner of the Dec. of Indep., framer of the Constitution of Mass., second President of the United Sta"
# igner of the Dec. of Indep., framer of the Constitution of Mass., second President of the United Stas yoanting Ockware millp a shart was GorgIth bebestor pors to at "Ru-sorde sonding in 1997 & yovalIn 1714,  pran Suxt. by, phay gonter forn, of of 2004, a, 20312tiel, a Unarg enat badk, of of end of,
# Epoch 25/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.1728 - categorical_crossentropy: 2.1728 - accuracy: 0.3805
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "ns with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours "
# ns with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of this seater a sounter of this searial a searsed this sears of the Carling to the ounder in 1994 these of the livel of the for the seater of the with a lears of this are the for the was a preater a
# ----- diversity: 0.5
# ----- Generating with seed: "ns with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours "
# ns with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours in these Danger of this seated has a celandan in serecher Hers pullay is theserscameded in these of these of the galles in 1862 this country is an to the eresed the ourt in 1996 "U.S. was below in onc
# ----- diversity: 1.0
# ----- Generating with seed: "ns with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours "
# ns with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours inse; Boycect)A bubfiansAsAsion"The Flis this 2040, os palnanda Onderlinigising calper af firles & Maglienonalsoperrof buce's its icluadain's fruter folts inese Proputy", sear", this aeorourruge, yost
# Epoch 26/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.1497 - categorical_crossentropy: 2.1497 - accuracy: 0.3890
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "hopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals f"
# hopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the seation the was the sean in 1965 this paine of this in this seation the peane of this first of this peane sian the seation in 1995 this counted in 1999 this sean in 1995 the were of the eanded
# ----- diversity: 0.5
# ----- Generating with seed: "hopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals f"
# hopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for a dican for the U.S. this ouce the manes in the mist seate wate for the singica in 1964 in 1994 he Andenting this Ame of this manises of this boye of this sean sione of this of the 1848 the a was i
# ----- diversity: 1.0
# ----- Generating with seed: "hopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals f"
# hopperBuilt in 312 B.C. to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals finged intcince dur-u1red ate Froy6 Poniess in arded" his whomeShew Mere in the  ange beaI "Wean injend realonTin Lange"B.Ade, it wase sionist to 19,0 Tune"In by firh A figwhuren in an Yoinaer Onome?sL
# Epoch 27/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.1429 - categorical_crossentropy: 2.1429 - accuracy: 0.3925
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: " billionth burgerSigner of the Dec. of Indep., framer of the Constitution of Mass., second President"
#  billionth burgerSigner of the Dec. of Indep., framer of the Constitution of Mass., second President in the stare of the for the firs the sean of the seat of the sear a plant of the sear in the sear the sean of the seat of the sear of the Anching the sear of this stare a sear in the sean a suring th
# ----- diversity: 0.5
# ----- Generating with seed: " billionth burgerSigner of the Dec. of Indep., framer of the Constitution of Mass., second President"
#  billionth burgerSigner of the Dec. of Indep., framer of the Constitution of Mass., second Presidentrom hes the frame in "This comourd tho ser the soun an on the har The rep of the sen the U.S. this was compary the U.S. Sestor a shere sear count in the in the for bed the spare on this comert red a b
# ----- diversity: 1.0
# ----- Generating with seed: " billionth burgerSigner of the Dec. of Indep., framer of the Constitution of Mass., second President"
#  billionth burgerSigner of the Dec. of Indep., framer of the Constitution of Mass., second PresidentaveTyiof d pafceatay for the ssare"The Andat Wery fased is EnountatlyInco younder "Gray of the hat this Seat in Ed of w , lighe who "The Agrean 15, moter erstorre you one 2 Peasion & the KestarkidThe
# Epoch 28/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.1144 - categorical_crossentropy: 2.1144 - accuracy: 0.3986
#
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ----- Generating with seed: "nkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., framer of the "
# nkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., framer of the with stard who "The stor the sente sent of the Brent of the sent of the seate was the sent in the sent in this stord of the stond in this start for the sent the for the sond whin this for the Aren thi
# ----- diversity: 0.5
# ----- Generating with seed: "nkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., framer of the "
# nkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., framer of the 1994 this lare sian in Eurs of a plone mary the bord dound war Rost Dancol a for this this dike this sounth whing in this Stote this 1995 he pand in 2000 he man the cown th s now Ching the 1994 Decan
# ----- diversity: 1.0
# ----- Generating with seed: "nkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., framer of the "
# nkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., framer of the Qurle the dla be, whis 948 "camat with 20, osk, thin In of dewn Chermo Rillng miar" "Gerring fern" "vert riaf)for's Sonco fron, Ho-shag, 'ln 1995Thil bar woonde's pror digre, lend wV. 2d sunch west te
# Epoch 29/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.1027 - categorical_crossentropy: 2.1027 - accuracy: 0.4015
#
# ----- Generating text after Epoch: 28
# ----- diversity: 0.2
# ----- Generating with seed: "his insect shared billing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it'"
# his insect shared billing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's and ander an a prenter in this priner of this country as ander of the sountry in the was her the linger of the was a player as a prines in this series of the seare of the Arerian of the sear share o
# ----- diversity: 0.5
# ----- Generating with seed: "his insect shared billing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it'"
# his insect shared billing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's seant of these for the from this player of the 2005 he pansing andere these from a sire in 1997 the U.S. was one mone of the seare of the mare in Jander starsh whith the serser wan this plays in 191
# ----- diversity: 1.0
# ----- Generating with seed: "his insect shared billing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it'"
# his insect shared billing with a grasshopperBuilt in 312 B.C. to link Rome & the South of Italy, it's pedpert's this ArA DiallyThis a0rN Tinch shisThi'm 200 deively, on a juonter plan on'n sees, thes preburth are berd a share is besPure to rhere prinePories Buling in hortcow injeghing oreah, Grousti
# Epoch 30/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.0872 - categorical_crossentropy: 2.0872 - accuracy: 0.4045
#
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: "todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72,"
# todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, he was the liter of the state of the litt the shate of the liter of the state of the first in the first of the seath of the state of the bert of the liter of the seated the proted the Sumping the was
# ----- diversity: 0.5
# ----- Generating with seed: "todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72,"
# todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, in the country the buck at the litt Mintry niter of the first in the senting a suris now the called the first of the Unewer play the country who beals as the first call the 1930s the first he with ma
# ----- diversity: 1.0
# ----- Generating with seed: "todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72,"
# todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, this this terting is sempton rallansed, "the ihis comestold the wand nameds... eretting MiSiaps, alver & o therThat ustariynr of thesesnor in Spuechery of this c purce this 1958 a On 14tt ,,t Su'lls
# Epoch 31/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.0668 - categorical_crossentropy: 2.0668 - accuracy: 0.4107
#
# ----- Generating text after Epoch: 30
# ----- diversity: 0.2
# ----- Generating with seed: "irmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, a record 1,122 inches of snow "
# irmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, a record 1,122 inches of snow seate of this compand of the parte of this compand of the U.S. the seate the sanded the was the seate of the first port of the first of the Sonter as a peact of this compane sort of this comper of the
# ----- diversity: 0.5
# ----- Generating with seed: "irmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, a record 1,122 inches of snow "
# irmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, a record 1,122 inches of snow to the fort besting country", "The Lany is the was the Unain fine in 1935 he this compers country that this paist first played the "Bent of this protican for the first in this country as the Seater as
# ----- diversity: 1.0
# ----- Generating with seed: "irmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, a record 1,122 inches of snow "
# irmingham Barons; 2,306 steals for the BullsIn the winter of 1971-72, a record 1,122 inches of snow a maker Late tit state of Layere U.S. gands it invoneviesThis bthin" mant or thas frimpoe Redery faist for thats indidastipe Dan ippreviaking the nomlanope fell was "this ionderI3 spetifzests film Fas
# Epoch 32/50
# 763/763 [==============================] - 3s 4ms/step - loss: 2.0474 - categorical_crossentropy: 2.0474 - accuracy: 0.4151
#
# ----- Generating text after Epoch: 31
# ----- diversity: 0.2
# ----- Generating with seed: " Linkletter Show", this company served its billionth burgerSigner of the Dec. of Indep., framer of t"
# ...
# ----- diversity: 1.0
# ----- Generating with seed: "the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunsh"
# the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunshive 2 yo 'egred the carred ereamern might rive was duel-foot" he nain stary for gith his notheny's hour "The Stak Elfls with In a Ferom Squirat Repord"Peees deseld of Noraking villing "sparturod of An
# Epoch 41/50
# 763/763 [==============================] - 3s 4ms/step - loss: 1.9045 - categorical_crossentropy: 1.9045 - accuracy: 0.4521
#
# ----- Generating text after Epoch: 40
# ----- diversity: 0.2
# ----- Generating with seed: "sons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hour"
# sons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hour start of the first of the first first pain in the first part of the large the land in 1965, he was the first pain for the first of the late river of the first country of the first part of the first p
# ----- diversity: 0.5
# ----- Generating with seed: "sons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hour"
# sons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hourn in the name name in the state from the seater as in the first have dreated the Same began a lander a "Frand Decound of the seat of the senr a cromber in the eland of the state for the hars the part
# ----- diversity: 1.0
# ----- Generating with seed: "sons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hour"
# sons with the Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 houring teesh of the perdon & NDM Eiralldided the littre of the "Alding with a seant creaternert burinamy & San 25 4000 younIn a rinele's havit "The barlThe "Buider as this line callastrulices of bro mega
# Epoch 42/50
# 763/763 [==============================] - 3s 4ms/step - loss: 1.8843 - categorical_crossentropy: 1.8843 - accuracy: 0.4583
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: "h of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the "
# h of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the seat of the state of the seat of this company that he was this compary that have of the seat of the seat the seat of this complay the name of this compored this compary that ham this compored this com
# ----- diversity: 0.5
# ----- Generating with seed: "h of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the "
# h of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the 1974 this comporded in whis liver in 1961, this month becan for this 1940s from the staded this companded a sooth the bark that hald the 1950s this callod the -old in the sapper of the staring the pra
# ----- diversity: 1.0
# ----- Generating with seed: "h of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the "
# h of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Barons; 2,306 steals for the Tervars if Ion of these in 1964 this toptall"Paling, ar a rucan for whee these is the montherst's this cart's comman the wathe with insuned this $1004-2Lees, in the 41lthiet somerndIn 1995 heIt by thi
# Epoch 43/50
# 763/763 [==============================] - 3s 4ms/step - loss: 1.8801 - categorical_crossentropy: 1.8801 - accuracy: 0.4623
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: "ball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in"
# ball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in the pereare of the part of the first pericersarded the seater of the for this seate of the first for the for the seater as the first poople of these for this country was a propures of the first was a
# ----- diversity: 0.5
# ----- Generating with seed: "ball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in"
# ball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in 1971 this goother for this Wirk Spotest for the fort with made the balled the Beathing of this country ployed for this 1962 book this stope of the mas of this Dearacting the hardest for the tay shore
# ----- diversity: 1.0
# ----- Generating with seed: "ball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma in"
# ball star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yuma include Stara 1701; teade forded for bashert blane deses '70s Heation's "meagis 381-degarateared by of the Pale mose...Dicollyvised worn recarded this sai You?"Filfed as hole sem fashout booquight U.S.T
# Epoch 44/50
# 763/763 [==============================] - 3s 4ms/step - loss: 1.8508 - categorical_crossentropy: 1.8508 - accuracy: 0.4674
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: " to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Baron"
#  to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Baron the was this compory the with the first called this company that his state this colling to this calling to was this country to the first in 1999 this country of the 1997 & this company of this countr
# ----- diversity: 0.5
# ----- Generating with seed: " to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Baron"
#  to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Baronie"Eartern mouth this the bean of "The River of the Schomes allote of this componaliversards this country's name is the player in this city of the Copound in the farse this alsed an airhing betere har
# ----- diversity: 1.0
# ----- Generating with seed: " to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Baron"
#  to link Rome & the South of Italy, it's still in use todayNo. 8: 30 steals for the Birmingham Baron with 2 17, in maishater meenhurd) & tragausest inj called"cond andonMinesA duforaillandor of whole's yon Nay "sjeakamulan Kentner, a cotyousseophed a siterememeation, "Tadlends is this Linnue'I Frent
# Epoch 45/50
# 763/763 [==============================] - 3s 4ms/step - loss: 1.8340 - categorical_crossentropy: 1.8340 - accuracy: 0.4713
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared"
# on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared the state of the ent of this country this country this controne in this country of this compury of this compored this country of this country this country of this country of this country whis at a co
# ----- diversity: 0.5
# ----- Generating with seed: "on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared"
# on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared the 1847 & "Todon's port racked the played this country conter conder of the state this controduce of an cander this 31000 Michic 1996 of the hering the erentrest country who name of this country of
# ----- diversity: 1.0
# ----- Generating with seed: "on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared"
# on of Mass., second President of the United StatesIn the title of an Aesop fable, this insect shared flow one white burast these from the young this formon arvicar buinhThe Bokis ert hald this and this citich of an apprake ootUnooction of somelifed indict of a, 1972It's uncerticesSinging withing; wh
# Epoch 46/50
# 763/763 [==============================] - 3s 3ms/step - loss: 1.8216 - categorical_crossentropy: 1.8216 - accuracy: 0.4751
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunshine "
# Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunshine state of the Conne was a senate of the Caring "In 1962 & the first senter of the Cania Record a part of the Carins a country west the first the state of the Caron a played the Carins a part of the Con
# ----- diversity: 0.5
# ----- Generating with seed: "Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunshine "
# Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunshine of this topreature in these name is the ard the ard this altaction pasters as the was the sected on a parst the sacco spender of the Canare famous the with menning with majest bulder of the bound the
# ----- diversity: 1.0
# ----- Generating with seed: "Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunshine "
# Reds, Giants & BravesThe city of Yuma in this state has a record average of 4,055 hours of sunshine farus, hvise in 1787 at 1,60 as hempioney were weland or the Gepoub 1818 foolsing queed's aflical spenced mentelm recousting vermbiel as Oscestivi& Smatel totire stati 1,0th ond Shet Anginaly;This fil
# Epoch 47/50
# 763/763 [==============================] - 3s 3ms/step - loss: 1.8030 - categorical_crossentropy: 1.8030 - accuracy: 0.4811
#
# ----- Generating text after Epoch: 46
# ----- diversity: 0.2
# ----- Generating with seed: "record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this "
# record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this state of the Art Antand in the fort the first popular souther was the first of the Conned in the first now her the for the first the first of the Are in the name of the 1994 foot the first the said to
# ----- diversity: 0.5
# ----- Generating with seed: "record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this "
# record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this state of the 1994 foot in the seated a dragat in the first a flag whose this from the land mouth a feations of the broties the Sand a was the name of the Touth of this was his for the Are Sheent of th
# ----- diversity: 1.0
# ----- Generating with seed: "record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this "
# record average of 4,055 hours of sunshine each yearIn 1963, live on "The Art Linkletter Show", this state in this fantur ceater l in with eade of the preated as grended this Geard in this sedber to lazan, Shotan Yargalt Jein's for the Penes Gidof Geee"In 2003 not the erchtcred port crnyplert Mays 35
# Epoch 48/50
# 763/763 [==============================] - 3s 3ms/step - loss: 1.7920 - categorical_crossentropy: 1.7920 - accuracy: 0.4826
#
# ----- Generating text after Epoch: 47
# ----- diversity: 0.2
# ----- Generating with seed: "; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Y"
# ; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of You "Ton the man has the name of the American porst of the name of the poperall for this mone of the sangent in the man in 1965 he was the first pape of the Arining "In 1962 this compinal popular in 19
# ----- diversity: 0.5
# ----- Generating with seed: "; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Y"
# ; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of You "Peen Ifort was a pristing of this to John a proples bulowashe rame whe name homman broth was spender Dan Have 1954 this country who name mogan searn banked in 1945A this south mongh wes man a born
# ----- diversity: 1.0
# ----- Generating with seed: "; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Y"
# ; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & BravesThe city of Yours's porkstrantion 1,002 TV Patifince Recon eary Pailfcolops&... centare, he! the hong to phunced that Anknial offerm for a groes is begins of Atriskevel"NubrankAnsI'm Boor TV Breed"The Whildwall of
# Epoch 49/50
# 763/763 [==============================] - 3s 4ms/step - loss: 1.7793 - categorical_crossentropy: 1.7793 - accuracy: 0.4868
#
# ----- Generating text after Epoch: 48
# ----- diversity: 0.2
# ----- Generating with seed: "t of the United StatesIn the title of an Aesop fable, this insect shared billing with a grasshopperB"
# t of the United StatesIn the title of an Aesop fable, this insect shared billing with a grasshopperBonder with the little of this first company that a speries from the sear the late of the little the seat of the seat of the sear the first played the first sanger of the seat of the seat of the seat o
# ----- diversity: 0.5
# ----- Generating with seed: "t of the United StatesIn the title of an Aesop fable, this insect shared billing with a grasshopperB"
# t of the United StatesIn the title of an Aesop fable, this insect shared billing with a grasshopperBect of the lirges the seat began it the said the name of this name that a staring this prince in the guiled "Colo Aland his langest the or a suries seat de in this singes for this guntry of the city o
# ----- diversity: 1.0
# ----- Generating with seed: "t of the United StatesIn the title of an Aesop fable, this insect shared billing with a grasshopperB"
# t of the United StatesIn the title of an Aesop fable, this insect shared billing with a grasshopperBects of 17tt FDe my a subbiel as it by the back his tut broe's served starge cress colf event's note nated for a low Garis sent, the latsht afreo this to card to bay hree-hor words worl this dingilatr
# Epoch 50/50
# 763/763 [==============================] - 3s 3ms/step - loss: 1.7606 - categorical_crossentropy: 1.7606 - accuracy: 0.4936
#
# ----- Generating text after Epoch: 49
# ----- diversity: 0.2
# ----- Generating with seed: "ne each yearIn 1963, live on "The Art Linkletter Show", this company served its billionth burgerSign"
# ne each yearIn 1963, live on "The Art Linkletter Show", this company served its billionth burgerSigner was dong to land in this country meass of the Consers of the said the first for the state of the state of the first sent conser of the sand to the state that a part the part of the seat senters of
# ----- diversity: 0.5
# ----- Generating with seed: "ne each yearIn 1963, live on "The Art Linkletter Show", this company served its billionth burgerSign"
# ne each yearIn 1963, live on "The Art Linkletter Show", this company served its billionth burgerSigner, the sent man preserts of these an one pover its senved the fort whose for the named for the Unit depperissinced a sarce bron better flag you's "Anchic was country beans of these from the Units of
# ----- diversity: 1.0
# ----- Generating with seed: "ne each yearIn 1963, live on "The Art Linkletter Show", this company served its billionth burgerSign"
# ne each yearIn 1963, live on "The Art Linkletter Show", this company served its billionth burgerSigned"In 1975 her istling art mest complays to Badry, or Millin in this KenificQurer 8 10 x 519th propratull spornWill"TheseEd nosess the Alshanction of thesents refor inngusene lack cortbe Frenched the
